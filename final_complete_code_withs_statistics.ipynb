# %% [markdown]
# <a href="https://colab.research.google.com/github/logonia/DAP/blob/main/final_complete_code_withs_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# COMPLETE CAPFG EXPERIMENT AND STATISTICAL VALIDATION SCRIPT
# - Full ablation (Baseline, MaskOnly, CapFGOnly, Full_CapFG)
# - Oxford-IIIT Pets classification + Dice evaluation
# - Statistical validation (10 seeds, 20 epochs each)
# Saves all results to CSV files.
# ============================================================

import os
import random
import time
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, lr_scheduler
from torch.utils.data import DataLoader, random_split, Subset, Dataset
from torchvision import datasets, transforms

# ---------------------------
# Set up device & reproducibility
# ---------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def set_seed(seed=42):
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# ---------------------------
# Helper functions
# ---------------------------
def squash(inputs, axis=-1):
    norm = torch.norm(inputs, p=2, dim=axis, keepdim=True)
    scale = (norm ** 2) / (1.0 + norm ** 2)
    return scale * inputs / (norm + 1e-8)

def to_onehot(y, num_classes):
    return torch.eye(num_classes, device=y.device)[y]

def caps_loss(y_true, y_pred, x, x_recon, lam_recon):
    margin = (y_true * torch.clamp(0.9 - y_pred, min=0.0)**2 +
              0.5 * (1.0 - y_true) * torch.clamp(y_pred - 0.1, min=0.0)**2)
    margin_loss = margin.sum(dim=1).mean()
    recon_loss = F.mse_loss(x_recon, x)
    return margin_loss + lam_recon * recon_loss

# ---------------------------
# Data loaders (CIFAR-10)
# ---------------------------
class ThresholdMaskTransform:
    def __init__(self, threshold):
        self.threshold = threshold
    def __call__(self, x):
        return x * (x > self.threshold).float()

class BackgroundNoiseTransform:
    def __init__(self, noise_std=0.25):
        self.noise_std = noise_std
    def __call__(self, x):
        return torch.clamp(x + torch.randn_like(x) * self.noise_std, 0.0, 1.0)

def load_cifar10(data_dir="./data", batch_size=128, val_size=5000, threshold=None, seed=42, split_seed=42):
    train_ops = [transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip(), transforms.ToTensor()]
    eval_ops = [transforms.ToTensor()]
    if threshold is not None:
        train_ops.append(ThresholdMaskTransform(threshold))
        eval_ops.append(ThresholdMaskTransform(threshold))

    train_tf = transforms.Compose(train_ops)
    eval_tf = transforms.Compose(eval_ops)

    full_train_aug = datasets.CIFAR10(data_dir, train=True, download=True, transform=train_tf)
    full_train_eval = datasets.CIFAR10(data_dir, train=True, download=False, transform=eval_tf)
    test_set = datasets.CIFAR10(data_dir, train=False, download=True, transform=eval_tf)

    total_len = len(full_train_aug)
    train_len = total_len - val_size
    train_subset, val_subset = random_split(range(total_len), [train_len, val_size],
                                            generator=torch.Generator().manual_seed(split_seed))
    train_set = Subset(full_train_aug, train_subset.indices)
    val_set = Subset(full_train_eval, val_subset.indices)

    pin = torch.cuda.is_available()
    g = torch.Generator().manual_seed(seed)
    train_loader = DataLoader(train_set, batch_size, shuffle=True, num_workers=2, pin_memory=pin,
                              worker_init_fn=seed_worker, generator=g)
    val_loader   = DataLoader(val_set, batch_size, shuffle=False, num_workers=2, pin_memory=pin,
                              worker_init_fn=seed_worker, generator=g)
    test_loader  = DataLoader(test_set, batch_size, shuffle=False, num_workers=2, pin_memory=pin,
                              worker_init_fn=seed_worker, generator=g)
    return train_loader, val_loader, test_loader

def load_cifar10_corrupted_test(data_dir="./data", batch_size=128, noise_std=0.25):
    transform = transforms.Compose([transforms.ToTensor(), BackgroundNoiseTransform(noise_std)])
    test_set = datasets.CIFAR10(data_dir, train=False, download=True, transform=transform)
    return DataLoader(test_set, batch_size, shuffle=False, num_workers=2, pin_memory=torch.cuda.is_available(),
                      worker_init_fn=seed_worker, generator=torch.Generator().manual_seed(42))

# ---------------------------
# Capsule components
# ---------------------------
class PrimaryCapsuleBase(nn.Module):
    def __init__(self, in_c=256, maps=32, dims=8):
        super().__init__()
        self.maps, self.dims = maps, dims
        self.conv = nn.Conv2d(in_c, maps*dims, 9, stride=2)
    def forward(self, x):
        out = self.conv(x)
        b, _, h, w = out.shape
        out = out.view(b, self.maps, self.dims, h, w).permute(0,1,3,4,2).contiguous()
        out = squash(out, axis=-1)
        return out.reshape(b, -1, self.dims), h, w

class PrimaryCapsuleUnsquashed(nn.Module):
    def __init__(self, in_c=256, maps=32, dims=8):
        super().__init__()
        self.maps, self.dims = maps, dims
        self.conv = nn.Conv2d(in_c, maps*dims, 9, stride=2)
    def forward(self, x):
        out = self.conv(x)
        b, _, h, w = out.shape
        out = out.view(b, self.maps, self.dims, h, w).permute(0,1,3,4,2).contiguous()
        raw_norms = torch.norm(out, dim=-1)
        return out, raw_norms, h, w

class DenseCapsule(nn.Module):
    def __init__(self, in_caps, out_caps, in_dims, out_dims, routings=3):
        super().__init__()
        self.in_caps = in_caps
        self.out_caps = out_caps
        self.routings = routings
        self.W = nn.Parameter(0.01 * torch.randn(out_caps, in_caps, out_dims, in_dims))
    def forward(self, x):
        u_hat = torch.einsum('bid,oijd->boij', x, self.W)
        b = torch.zeros(x.size(0), self.out_caps, self.in_caps, device=x.device)
        for i in range(self.routings):
            c = F.softmax(b, dim=1)
            s = (c.unsqueeze(-1) * u_hat).sum(dim=2)
            v = squash(s, axis=-1)
            if i < self.routings-1:
                b = b + (u_hat * v.unsqueeze(2)).sum(dim=-1)
        return v

class ImprovedCapFG(nn.Module):
    def __init__(self, in_maps=32, beta=0.2, entropy_weight=0.01, magnitude_weight=0.0, target_mean=0.3):
        super().__init__()
        self.beta = beta
        self.entropy_weight = entropy_weight
        self.magnitude_weight = magnitude_weight
        self.target_mean = target_mean
        self.local = nn.Sequential(
            nn.Conv2d(in_maps, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(inplace=True),
            nn.Conv2d(32, 16, 3, padding=1), nn.BatchNorm2d(16), nn.ReLU(inplace=True),
            nn.Conv2d(16, 1, 1)
        )
        self.global_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(in_maps, 1)
        self.temperature = nn.Parameter(torch.tensor(1.0))
    def forward(self, raw_norms):
        logits = self.local(raw_norms)
        g = torch.sigmoid(self.fc(self.global_pool(raw_norms).flatten(1)))
        logits = logits * g[:, :, None, None]
        return torch.sigmoid(logits / self.temperature)
    def entropy_loss(self, mask):
        m = mask.view(mask.size(0), -1)
        entropy = -torch.mean(m * torch.log(m+1e-8) + (1-m)*torch.log(1-m+1e-8))
        return self.entropy_weight * entropy
    def magnitude_loss(self, mask):
        mean_act = mask.mean()
        return self.magnitude_weight * F.relu(self.target_mean - mean_act)

class CapsuleNetAblation(nn.Module):
    def __init__(self, shape=(3,32,32), classes=10, routings=3,
                 use_input_mask=False, use_capfg=False, mask_threshold=0.1,
                 beta=0.2, entropy_weight=0.01, magnitude_weight=0.0, target_mean=0.3):
        super().__init__()
        self.shape = shape
        self.classes = classes
        self.use_input_mask = use_input_mask
        self.use_capfg = use_capfg
        self.mask_threshold = mask_threshold

        self.conv1 = nn.Conv2d(shape[0], 256, kernel_size=9, stride=1, padding=0)
        self.relu = nn.ReLU(inplace=True)

        if use_capfg:
            self.primary = PrimaryCapsuleUnsquashed(256, 32, 8)
            self.mask_gen = ImprovedCapFG(32, beta=beta, entropy_weight=entropy_weight,
                                          magnitude_weight=magnitude_weight, target_mean=target_mean)
            self.num_caps_in = 32 * 8 * 8
        else:
            self.primary = PrimaryCapsuleBase(256, 32, 8)
            self.num_caps_in = 32 * 8 * 8

        self.digitcaps = DenseCapsule(self.num_caps_in, classes, 8, 16, routings)
        self.decoder = nn.Sequential(
            nn.Linear(16*classes, 512), nn.ReLU(inplace=True),
            nn.Linear(512, 1024), nn.ReLU(inplace=True),
            nn.Linear(1024, shape[0]*shape[1]*shape[2]), nn.Sigmoid()
        )

    def forward(self, x, y=None, return_mask=False):
        if self.use_input_mask:
            x = x * (x > self.mask_threshold).float()
        out = self.relu(self.conv1(x))
        if self.use_capfg:
            prim_unsq, raw_norms, h, w = self.primary(out)
            mask = self.mask_gen(raw_norms)
            mask_exp = mask.unsqueeze(-1)
            prim_masked = prim_unsq * mask_exp + prim_unsq * self.mask_gen.beta * (1 - mask_exp)
            prim_squashed = squash(prim_masked, axis=-1)
            prim_flat = prim_squashed.view(x.size(0), -1, 8)
        else:
            prim_flat, h, w = self.primary(out)
        out = self.digitcaps(prim_flat)
        length = out.norm(dim=-1)
        if y is None:
            idx = length.max(1)[1]
            y = torch.eye(self.classes, device=x.device)[idx]
        recon = self.decoder((out * y[:,:,None]).view(out.size(0), -1))
        recon = recon.view(-1, *self.shape)
        if return_mask and self.use_capfg:
            return length, recon, mask
        return length, recon

    def mask_extra_losses(self, mask):
        if self.use_capfg:
            return self.mask_gen.entropy_loss(mask) + self.mask_gen.magnitude_loss(mask)
        return torch.tensor(0.0, device=device)

# ---------------------------
# Training and evaluation
# ---------------------------
def evaluate_capsule(model, loader, lam_recon, num_classes, use_mask_loss=False):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            y_onehot = to_onehot(y, num_classes)
            if use_mask_loss and hasattr(model, 'mask_extra_losses'):
                y_pred, x_recon, mask = model(x, return_mask=True)
                loss = caps_loss(y_onehot, y_pred, x, x_recon, lam_recon) + model.mask_extra_losses(mask)
            else:
                y_pred, x_recon = model(x)
                loss = caps_loss(y_onehot, y_pred, x, x_recon, lam_recon)
            total_loss += loss.item() * x.size(0)
            correct += (y_pred.argmax(1) == y).sum().item()
            total += x.size(0)
    return total_loss / total, correct / total

def train_one_run(model, train_loader, val_loader, config, use_mask_loss=False, model_name="model"):
    opt = Adam(model.parameters(), lr=config['lr'])
    sched = lr_scheduler.ExponentialLR(opt, gamma=config['lr_decay'])
    best_acc = -1.0
    best_epoch = 0
    best_state = None
    history = []

    for epoch in range(config['epochs']):
        model.train()
        train_loss_sum, train_total = 0.0, 0
        start = time.time()

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            y_onehot = to_onehot(y, config['classes'])
            opt.zero_grad()
            if use_mask_loss and hasattr(model, 'mask_extra_losses'):
                y_pred, x_recon, mask = model(x, y_onehot, return_mask=True)
                loss = caps_loss(y_onehot, y_pred, x, x_recon, config['lam_recon']) + model.mask_extra_losses(mask)
            else:
                y_pred, x_recon = model(x, y_onehot)
                loss = caps_loss(y_onehot, y_pred, x, x_recon, config['lam_recon'])
            loss.backward()
            opt.step()
            train_loss_sum += loss.item() * x.size(0)
            train_total += x.size(0)

        sched.step()
        train_loss = train_loss_sum / train_total
        val_loss, val_acc = evaluate_capsule(model, val_loader, config['lam_recon'], config['classes'], use_mask_loss)
        epoch_time = time.time() - start

        if val_acc > best_acc:
            best_acc = val_acc
            best_epoch = epoch + 1
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

        history.append({
            'model': model_name,
            'epoch': epoch + 1,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'val_acc': val_acc,
            'epoch_time_sec': epoch_time,
        })
        print(f"  {model_name} | Epoch {epoch+1:02d}/{config['epochs']} | "
              f"train_loss={train_loss:.4f} | val_loss={val_loss:.4f} | "
              f"val_acc={val_acc:.4f} | best={best_acc:.4f} @ epoch {best_epoch}")

    if best_state is not None:
        model.load_state_dict(best_state)
    return best_acc, best_epoch, pd.DataFrame(history)

# ---------------------------
# Analysis functions
# ---------------------------
def get_primary_capsules_for_routing(model, x, apply_capfg=True):
    if model.use_input_mask:
        x_in = x * (x > model.mask_threshold).float()
    else:
        x_in = x
    out = model.relu(model.conv1(x_in))
    if model.use_capfg:
        prim_unsq, raw_norms, h, w = model.primary(out)
        if apply_capfg:
            mask = model.mask_gen(raw_norms)
            mask_exp = mask.unsqueeze(-1)
            prim_masked = prim_unsq * mask_exp + prim_unsq * model.mask_gen.beta * (1 - mask_exp)
            prim_squashed = squash(prim_masked, axis=-1)
        else:
            prim_squashed = squash(prim_unsq, axis=-1)
        prim_flat = prim_squashed.view(x.size(0), -1, 8)
    else:
        prim_flat, h, w = model.primary(out)
    return prim_flat

def compute_routing_metrics(model, loader, device, apply_capfg=True, max_batches=None):
    model.eval()
    all_weighted_agreements = []
    all_mean_dot_agreements = []
    all_entropies = []
    with torch.no_grad():
        for batch_idx, (x, y) in enumerate(loader):
            if max_batches is not None and batch_idx >= max_batches:
                break
            x = x.to(device)
            prim_flat = get_primary_capsules_for_routing(model, x, apply_capfg=apply_capfg)
            digitcaps = model.digitcaps
            u_hat = torch.einsum('bid,oijd->boij', prim_flat, digitcaps.W)
            b = torch.zeros(x.size(0), digitcaps.out_caps, digitcaps.in_caps, device=x.device)
            for i in range(digitcaps.routings):
                c = F.softmax(b, dim=1)
                s = (c.unsqueeze(-1) * u_hat).sum(dim=2)
                v = squash(s, axis=-1)
                dot_agreement = (u_hat * v.unsqueeze(2)).sum(dim=-1)
                if i < digitcaps.routings - 1:
                    b = b + dot_agreement
            c_final = F.softmax(b, dim=1)
            s_final = (c_final.unsqueeze(-1) * u_hat).sum(dim=2)
            v_final = squash(s_final, axis=-1)
            dot_final = (u_hat * v_final.unsqueeze(2)).sum(dim=-1)
            weighted_agreement = (c_final * dot_final).sum(dim=1).mean(dim=1)
            mean_dot_agreement = dot_final.mean(dim=(1,2))
            entropy = -(c_final * torch.log(c_final + 1e-8)).sum(dim=1).mean(dim=1)
            all_weighted_agreements.extend(weighted_agreement.cpu().numpy())
            all_mean_dot_agreements.extend(mean_dot_agreement.cpu().numpy())
            all_entropies.extend(entropy.cpu().numpy())
    return {
        'weighted_agreement_mean': float(np.mean(all_weighted_agreements)),
        'weighted_agreement_std': float(np.std(all_weighted_agreements)),
        'mean_dot_agreement_mean': float(np.mean(all_mean_dot_agreements)),
        'mean_dot_agreement_std': float(np.std(all_mean_dot_agreements)),
        'routing_entropy_mean': float(np.mean(all_entropies)),
        'routing_entropy_std': float(np.std(all_entropies)),
    }

def run_shortcut_diagnostic(baseline_model, full_model, test_loader, device, baseline_orig_acc, full_orig_acc):
    baseline_model.eval()
    full_model.eval()
    baseline_correct, full_correct, total = 0, 0, 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            outer_mask = torch.ones_like(x)
            outer_mask[:, :, 8:24, 8:24] = 0.0
            noise = torch.randn_like(x) * 0.5
            x_shifted = torch.clamp(x * (1 - outer_mask) + noise * outer_mask, 0, 1)
            y_pred, _ = baseline_model(x_shifted)
            baseline_correct += (y_pred.argmax(1) == y).sum().item()
            y_pred, _ = full_model(x_shifted)
            full_correct += (y_pred.argmax(1) == y).sum().item()
            total += x.size(0)
    return {
        'baseline_shifted_acc': baseline_correct / total,
        'full_shifted_acc': full_correct / total,
        'baseline_drop': baseline_orig_acc - baseline_correct / total,
        'full_drop': full_orig_acc - full_correct / total,
    }

def evaluate_noise_robustness(models, loader_func, config, noise_levels=(0.0, 0.1, 0.2, 0.3)):
    rows = []
    for nl in noise_levels:
        if nl == 0.0:
            _, _, loader = load_cifar10(batch_size=config['batch_size'])
        else:
            loader = loader_func(batch_size=config['batch_size'], noise_std=nl)
        for model_name, model, use_mask_loss in models:
            _, acc = evaluate_capsule(model, loader, config['lam_recon'], config['classes'], use_mask_loss=use_mask_loss)
            rows.append({'noise_std': nl, 'model': model_name, 'accuracy': acc})
    df = pd.DataFrame(rows)
    wide = df.pivot(index='noise_std', columns='model', values='accuracy').reset_index()
    if 'Baseline' in wide.columns and 'Full_CapFG' in wide.columns:
        wide['Full_minus_Baseline'] = wide['Full_CapFG'] - wide['Baseline']
    return df, wide

def compute_per_class_metrics(model, loader, device):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            y_pred, _ = model(x)
            all_preds.extend(y_pred.argmax(1).cpu().numpy())
            all_labels.extend(y.cpu().numpy())
    precision, recall, f1, support = precision_recall_fscore_support(
        all_labels, all_preds, labels=range(10), average=None, zero_division=0
    )
    return precision, recall, f1, support

def measure_cost(model, input_shape, batch_size=128, warmup=20, repeats=100):
    model.eval()
    params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    flops = None
    try:
        from thop import profile
        dummy = torch.randn(1, *input_shape).to(device)
        flops, _ = profile(model, inputs=(dummy,), verbose=False)
    except Exception as e:
        print(f"FLOPs not computed for {model.__class__.__name__}: {e}")
    dummy = torch.randn(batch_size, *input_shape).to(device)
    with torch.no_grad():
        for _ in range(warmup):
            _ = model(dummy)
        if torch.cuda.is_available():
            torch.cuda.synchronize()
        start = time.time()
        for _ in range(repeats):
            _ = model(dummy)
        if torch.cuda.is_available():
            torch.cuda.synchronize()
        elapsed = time.time() - start
    ms_per_batch = elapsed / repeats * 1000
    ms_per_image = ms_per_batch / batch_size
    return {
        'parameters': params,
        'trainable_parameters': trainable_params,
        'parameters_M': params / 1e6,
        'FLOPs': flops,
        'FLOPs_M': flops / 1e6 if flops is not None else np.nan,
        'inference_ms_per_batch': ms_per_batch,
        'inference_ms_per_image': ms_per_image,
    }

def summarize_training_dynamics(history_df):
    rows = []
    for model_name, g in history_df.groupby('model'):
        best_val = g['val_acc'].max()
        best_epoch = int(g.loc[g['val_acc'].idxmax(), 'epoch'])
        threshold_95 = 0.95 * best_val
        epochs_to_95 = int(g[g['val_acc'] >= threshold_95]['epoch'].min())
        last5_var = float(g.tail(5)['val_acc'].var(ddof=1)) if len(g) >= 5 else np.nan
        rows.append({
            'model': model_name,
            'best_val_acc': best_val,
            'best_epoch': best_epoch,
            'epochs_to_95pct_best': epochs_to_95,
            'final_train_loss': float(g.iloc[-1]['train_loss']),
            'final_val_loss': float(g.iloc[-1]['val_loss']),
            'mean_epoch_time_sec': float(g['epoch_time_sec'].mean()),
            'val_acc_variance_last5': last5_var,
        })
    return pd.DataFrame(rows)


# ---------------------------
# Confusion matrix, macro metrics, threshold sensitivity, and figures
# ---------------------------
def collect_predictions(model, loader, device):
    model.eval()
    preds, labels = [], []
    with torch.no_grad():
        for batch in loader:
            if len(batch) == 3:
                x, y, _ = batch
            else:
                x, y = batch
            x, y = x.to(device), y.to(device)
            y_pred, _ = model(x)
            preds.extend(y_pred.argmax(1).cpu().numpy())
            labels.extend(y.cpu().numpy())
    return np.asarray(labels), np.asarray(preds)


def save_confusion_matrix_figure(baseline_model, full_model, test_loader, class_names,
                                 out_png='cifar10_confusion_matrices.png'):
    y_true_b, y_pred_b = collect_predictions(baseline_model, test_loader, device)
    y_true_f, y_pred_f = collect_predictions(full_model, test_loader, device)

    cm_b = confusion_matrix(y_true_b, y_pred_b, labels=range(len(class_names)))
    cm_f = confusion_matrix(y_true_f, y_pred_f, labels=range(len(class_names)))

    # Save raw matrices too
    pd.DataFrame(cm_b, index=class_names, columns=class_names).to_csv(
        'cifar10_confusion_matrix_baseline.csv'
    )
    pd.DataFrame(cm_f, index=class_names, columns=class_names).to_csv(
        'cifar10_confusion_matrix_full_capfg.csv'
    )

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    disp_b = ConfusionMatrixDisplay(cm_b, display_labels=class_names)
    disp_b.plot(ax=axes[0], cmap='Blues', colorbar=False, xticks_rotation=45)
    axes[0].set_title('Baseline CapsNet')

    disp_f = ConfusionMatrixDisplay(cm_f, display_labels=class_names)
    disp_f.plot(ax=axes[1], cmap='Blues', colorbar=False, xticks_rotation=45)
    axes[1].set_title('Full CapFG')

    plt.tight_layout()
    plt.savefig(out_png, dpi=300, bbox_inches='tight')
    plt.close(fig)

    return cm_b, cm_f


def save_training_dynamics_figure(history_df,
                                  out_png='cifar10_training_dynamics.png'):
    wanted = history_df[
        history_df['model'].isin(['CIFAR10_Baseline', 'CIFAR10_Full_CapFG'])
    ].copy()

    if wanted.empty:
        print("Warning: representative Baseline/Full histories were not found.")
        return

    fig, axes = plt.subplots(1, 2, figsize=(13, 5))

    for model_name, g in wanted.groupby('model'):
        short_name = model_name.replace('CIFAR10_', '')
        axes[0].plot(g['epoch'], g['train_loss'], label=short_name)
        axes[1].plot(g['epoch'], g['val_acc'], label=short_name)

    axes[0].set_title('Training Loss')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].legend()

    axes[1].set_title('Validation Accuracy')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()

    plt.tight_layout()
    plt.savefig(out_png, dpi=300, bbox_inches='tight')
    plt.close(fig)


def compute_macro_metrics(model, loader, device):
    y_true, y_pred = collect_predictions(model, loader, device)
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_true, y_pred, average='macro', zero_division=0
    )
    accuracy = float((y_true == y_pred).mean())
    return {
        'accuracy': accuracy,
        'macro_precision': float(precision),
        'macro_recall': float(recall),
        'macro_f1': float(f1),
    }


def run_threshold_sensitivity(config, thresholds=(0.05, 0.10, 0.15, 0.20),
                              seeds=(11, 22, 33), epochs=15):
    """
    Screening analysis for the auxiliary input-mask threshold.
    Uses MaskOnly and Full_CapFG across a small fixed seed set.
    This is intentionally lighter than the 10-seed confirmatory analysis.
    """
    rows = []
    specs = [
        {'name': 'MaskOnly', 'use_input_mask': True, 'use_capfg': False, 'use_mask_loss': False},
        {'name': 'Full_CapFG', 'use_input_mask': True, 'use_capfg': True, 'use_mask_loss': True},
    ]

    cfg = config.copy()
    cfg['epochs'] = epochs

    for threshold in thresholds:
        for seed in seeds:
            set_seed(seed)
            train_loader, val_loader, test_loader = load_cifar10(
                batch_size=cfg['batch_size'],
                seed=seed,
                split_seed=42
            )

            for spec in specs:
                set_seed(seed)
                model = CapsuleNetAblation(
                    shape=(3, 32, 32),
                    classes=10,
                    use_input_mask=spec['use_input_mask'],
                    use_capfg=spec['use_capfg'],
                    mask_threshold=threshold,
                    beta=cfg['capfg_beta'],
                    entropy_weight=cfg['capfg_entropy_weight'],
                    magnitude_weight=cfg['capfg_magnitude_weight'],
                    target_mean=cfg['capfg_target_mean'],
                ).to(device)

                best_val, best_epoch, _ = train_one_run(
                    model, train_loader, val_loader, cfg,
                    use_mask_loss=spec['use_mask_loss'],
                    model_name=f"THR_{threshold}_{seed}_{spec['name']}"
                )

                _, test_acc = evaluate_capsule_loader3_safe(
                    model, test_loader, cfg['lam_recon'], 10, spec['use_mask_loss']
                )

                rows.append({
                    'threshold': threshold,
                    'seed': seed,
                    'model': spec['name'],
                    'best_val_acc': best_val,
                    'best_epoch': best_epoch,
                    'test_acc': test_acc,
                })

                del model
                if torch.cuda.is_available():
                    torch.cuda.empty_cache()

    long_df = pd.DataFrame(rows)
    summary_df = (
        long_df.groupby(['threshold', 'model'])['test_acc']
        .agg(['mean', 'std', 'count'])
        .reset_index()
    )
    long_df.to_csv('cifar10_threshold_sensitivity_runs.csv', index=False)
    summary_df.to_csv('cifar10_threshold_sensitivity_summary.csv', index=False)
    return long_df, summary_df


def save_all_results_excel(output_file, tables):
    """Save all result tables to a single Excel workbook for convenience."""
    try:
        with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
            for sheet_name, df in tables.items():
                if df is not None and isinstance(df, pd.DataFrame) and not df.empty:
                    safe = sheet_name[:31]
                    df.to_excel(writer, sheet_name=safe, index=False)
        print(f"Saved consolidated workbook: {output_file}")
    except Exception as e:
        print(f"Could not save Excel workbook: {e}")


# ---------------------------
# Oxford-IIIT Pets dataset
# ---------------------------
class OxfordPetsClsDataset(Dataset):
    def __init__(self, split='trainval', img_size=32, return_mask=False):
        self.return_mask = return_mask
        target_types = ['category', 'segmentation'] if return_mask else 'category'
        self.ds = datasets.OxfordIIITPet(
            root='./data', split=split, target_types=target_types, download=True
        )
        self.image_tf = transforms.Compose([
            transforms.Resize((img_size, img_size)),
            transforms.ToTensor(),
        ])
        self.mask_tf = transforms.Compose([
            transforms.Resize((img_size, img_size), interpolation=transforms.InterpolationMode.NEAREST),
            transforms.PILToTensor(),
        ])
    def __len__(self):
        return len(self.ds)
    def __getitem__(self, idx):
        if self.return_mask:
            img, target = self.ds[idx]
            label, seg = target
            x = self.image_tf(img)
            seg_t = self.mask_tf(seg).float().squeeze(0)
            fg = (seg_t != 2).float().unsqueeze(0)  # 1=foreground, 0=background
            return x, int(label), fg
        img, label = self.ds[idx]
        return self.image_tf(img), int(label)

def load_oxford_pets(batch_size=64, val_size=700, seed=42, img_size=32):
    trainval = OxfordPetsClsDataset(split='trainval', img_size=img_size, return_mask=False)
    test_cls = OxfordPetsClsDataset(split='test', img_size=img_size, return_mask=False)
    test_mask = OxfordPetsClsDataset(split='test', img_size=img_size, return_mask=True)

    train_len = len(trainval) - val_size
    g = torch.Generator().manual_seed(seed)
    train_ds, val_ds = random_split(trainval, [train_len, val_size], generator=g)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2,
                              worker_init_fn=seed_worker, generator=torch.Generator().manual_seed(seed))
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=2)
    test_loader = DataLoader(test_cls, batch_size=batch_size, shuffle=False, num_workers=2)
    dice_loader = DataLoader(test_mask, batch_size=batch_size, shuffle=False, num_workers=2)
    return train_loader, val_loader, test_loader, dice_loader

def evaluate_capsule_loader3_safe(model, loader, lam_recon, num_classes, use_mask_loss=False):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for batch in loader:
            if len(batch) == 3:
                x, y, _ = batch
            else:
                x, y = batch
            x, y = x.to(device), y.to(device)
            y_onehot = to_onehot(y, num_classes)
            if use_mask_loss and hasattr(model, 'mask_extra_losses'):
                y_pred, x_recon, mask = model(x, return_mask=True)
                loss = caps_loss(y_onehot, y_pred, x, x_recon, lam_recon) + model.mask_extra_losses(mask)
            else:
                y_pred, x_recon = model(x)
                loss = caps_loss(y_onehot, y_pred, x, x_recon, lam_recon)
            total_loss += loss.item() * x.size(0)
            correct += (y_pred.argmax(1) == y).sum().item()
            total += x.size(0)
    return total_loss / total, correct / total

def evaluate_capfg_dice(model, dice_loader, device, threshold=0.5, max_batches=None):
    if not hasattr(model, 'mask_gen') or model.mask_gen is None:
        return {'mean_dice': np.nan, 'std_dice': np.nan, 'n_images': 0}
    model.eval()
    dice_scores = []
    with torch.no_grad():
        for b, (x, y, true_mask) in enumerate(dice_loader):
            if max_batches is not None and b >= max_batches:
                break
            x = x.to(device)
            true_mask = true_mask.to(device)
            if true_mask.dim() == 3:
                true_mask = true_mask.unsqueeze(1)
            _, _, learned_mask = model(x, return_mask=True)
            if learned_mask.dim() == 3:
                learned_mask = learned_mask.unsqueeze(1)
            pred_mask = F.interpolate(learned_mask, size=true_mask.shape[-2:], mode='bilinear', align_corners=False)
            pred_bin = (pred_mask >= threshold).float()
            intersection = (pred_bin * true_mask).sum(dim=(1,2,3))
            union = pred_bin.sum(dim=(1,2,3)) + true_mask.sum(dim=(1,2,3))
            dice = (2 * intersection + 1e-8) / (union + 1e-8)
            dice_scores.extend(dice.cpu().numpy().tolist())
    return {
        'mean_dice': float(np.mean(dice_scores)) if dice_scores else np.nan,
        'std_dice': float(np.std(dice_scores, ddof=1)) if len(dice_scores) > 1 else np.nan,
        'n_images': len(dice_scores),
    }

# ---------------------------
# Ablation runner
# ---------------------------
def train_ablation_on_dataset(dataset_name, train_loader, val_loader, test_loader, config, experiment_specs,
                              classes, output_prefix, shape=(3,32,32), save_models=True):
    models = {}
    histories = []
    clean_rows = []
    old_classes = config['classes']
    config['classes'] = classes

    for spec in experiment_specs:
        print(f"\n--- [{dataset_name}] Training {spec['name']} for {config['epochs']} epochs ---")
        model = CapsuleNetAblation(
            shape=shape,
            classes=classes,
            use_input_mask=spec['use_input_mask'],
            use_capfg=spec['use_capfg'],
            mask_threshold=config['capfg_threshold'],
            beta=config['capfg_beta'],
            entropy_weight=config['capfg_entropy_weight'],
            magnitude_weight=config['capfg_magnitude_weight'],
            target_mean=config['capfg_target_mean'],
        ).to(device)

        best_val, best_epoch, hist = train_one_run(
            model, train_loader, val_loader, config,
            use_mask_loss=spec['use_mask_loss'], model_name=f"{dataset_name}_{spec['name']}"
        )
        if save_models:
            torch.save(model.state_dict(), f"{output_prefix}_{spec['name'].lower()}_best.pt")
        models[spec['name']] = model
        histories.append(hist)

        test_loss, test_acc = evaluate_capsule_loader3_safe(
            model, test_loader, config['lam_recon'], classes, spec['use_mask_loss']
        )
        clean_rows.append({
            'dataset': dataset_name,
            'model': spec['name'],
            'best_val_acc': best_val,
            'best_epoch': best_epoch,
            'test_loss': test_loss,
            'test_acc': test_acc,
        })

    config['classes'] = old_classes
    return models, pd.DataFrame(clean_rows), pd.concat(histories, ignore_index=True)

# ---------------------------
# Statistical validation helpers
# ---------------------------
def _mean_ci95(values):
    values = np.asarray(values, dtype=float)
    n = len(values)
    mean = float(np.mean(values))
    sd = float(np.std(values, ddof=1)) if n > 1 else np.nan
    if n > 1:
        sem = stats.sem(values)
        tcrit = stats.t.ppf(0.975, df=n - 1)
        ci_low = float(mean - tcrit * sem)
        ci_high = float(mean + tcrit * sem)
    else:
        ci_low = np.nan
        ci_high = np.nan
    return mean, sd, ci_low, ci_high

def run_repeated_seed_statistics(config, seeds=(11, 22, 33, 44, 55, 66, 77, 88, 99, 101), split_seed=42):
    specs = [
        {'name': 'Baseline', 'use_input_mask': False, 'use_capfg': False, 'use_mask_loss': False},
        {'name': 'Full_CapFG', 'use_input_mask': True, 'use_capfg': True, 'use_mask_loss': True},
    ]

    rows = []

    for seed in seeds:
        print(f"\n================ STATISTICAL RUN: seed={seed} ================")
        set_seed(seed)

        train_loader, val_loader, test_loader = load_cifar10(
            batch_size=config['batch_size'],
            seed=seed,
            split_seed=split_seed
        )

        for spec in specs:
            print(f"\n--- Statistical validation | seed={seed} | {spec['name']} ---")
            set_seed(seed)

            model = CapsuleNetAblation(
                shape=(3, 32, 32),
                classes=10,
                use_input_mask=spec['use_input_mask'],
                use_capfg=spec['use_capfg'],
                mask_threshold=config['capfg_threshold'],
                beta=config['capfg_beta'],
                entropy_weight=config['capfg_entropy_weight'],
                magnitude_weight=config['capfg_magnitude_weight'],
                target_mean=config['capfg_target_mean'],
            ).to(device)

            best_val, best_epoch, _ = train_one_run(
                model,
                train_loader,
                val_loader,
                config,
                use_mask_loss=spec['use_mask_loss'],
                model_name=f"STAT_seed{seed}_{spec['name']}"
            )

            test_loss, test_acc = evaluate_capsule_loader3_safe(
                model,
                test_loader,
                config['lam_recon'],
                10,
                spec['use_mask_loss']
            )

            rows.append({
                'seed': seed,
                'model': spec['name'],
                'best_val_acc': best_val,
                'best_epoch': best_epoch,
                'test_loss': test_loss,
                'test_acc': test_acc,
            })

            del model
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

    runs_df = pd.DataFrame(rows)

    paired = runs_df.pivot(index='seed', columns='model', values='test_acc').dropna()
    paired['difference_full_minus_baseline'] = paired['Full_CapFG'] - paired['Baseline']

    baseline = paired['Baseline'].to_numpy()
    full = paired['Full_CapFG'].to_numpy()
    diff = paired['difference_full_minus_baseline'].to_numpy()

    summary_rows = []
    for model_name in ['Baseline', 'Full_CapFG']:
        vals = paired[model_name].to_numpy()
        mean, sd, ci_low, ci_high = _mean_ci95(vals)
        summary_rows.append({
            'model': model_name,
            'n_runs': len(vals),
            'mean_test_acc': mean,
            'std_test_acc': sd,
            'ci95_low': ci_low,
            'ci95_high': ci_high,
        })

    diff_mean, diff_sd, diff_ci_low, diff_ci_high = _mean_ci95(diff)

    # Paired t-test
    t_stat, p_value = stats.ttest_rel(full, baseline)

    # Shapiro-Wilk normality test on paired differences
    if len(diff) >= 3:
        shapiro_stat, shapiro_p = stats.shapiro(diff)
    else:
        shapiro_stat, shapiro_p = np.nan, np.nan

    try:
        w_stat, w_p = stats.wilcoxon(full, baseline, alternative='two-sided')
    except ValueError:
        w_stat, w_p = np.nan, np.nan

    cohens_dz = diff_mean / diff_sd if diff_sd and not np.isnan(diff_sd) and diff_sd > 0 else np.nan

    inferential_df = pd.DataFrame([{
        'comparison': 'Full_CapFG - Baseline',
        'n_pairs': len(diff),
        'mean_difference': diff_mean,
        'std_difference': diff_sd,
        'difference_ci95_low': diff_ci_low,
        'difference_ci95_high': diff_ci_high,
        'paired_t_statistic': float(t_stat),
        'paired_t_pvalue': float(p_value),
        'shapiro_difference_statistic': float(shapiro_stat) if not np.isnan(shapiro_stat) else np.nan,
        'shapiro_difference_pvalue': float(shapiro_p) if not np.isnan(shapiro_p) else np.nan,
        'wilcoxon_statistic': float(w_stat) if not np.isnan(w_stat) else np.nan,
        'wilcoxon_pvalue': float(w_p) if not np.isnan(w_p) else np.nan,
        'cohens_dz': float(cohens_dz) if not np.isnan(cohens_dz) else np.nan,
    }])

    summary_df = pd.DataFrame(summary_rows)

    print("\n=== Repeated-run per-seed results ===")
    print(runs_df)
    print("\n=== Descriptive statistical summary ===")
    print(summary_df)
    print("\n=== Paired inferential statistics ===")
    print(inferential_df)

    runs_df.to_csv('cifar10_repeated_seed_runs.csv', index=False)
    paired.reset_index().to_csv('cifar10_paired_seed_accuracies.csv', index=False)
    summary_df.to_csv('cifar10_statistical_summary.csv', index=False)
    inferential_df.to_csv('cifar10_inferential_statistics.csv', index=False)

    return runs_df, summary_df, inferential_df

# ---------------------------
# MAIN
# ---------------------------
def main():
    config = {
        'epochs': 30,
        'batch_size': 128,
        'pets_batch_size': 64,
        'lr': 0.001,
        'lr_decay': 0.9,
        'lam_recon': 0.0005 * 3 * 32 * 32,
        'classes': 10,
        'capfg_threshold': 0.10,
        'capfg_beta': 0.20,
        'capfg_entropy_weight': 0.01,
        'capfg_magnitude_weight': 0.0,
        'capfg_target_mean': 0.30,
        'run_pets_ablation': True,
        'run_statistical_validation': True,
        'statistical_seeds': [11, 22, 33, 44, 55, 66, 77, 88, 99, 101],
        'statistical_split_seed': 42,
        'statistical_epochs': 30,
        'run_threshold_sensitivity': True,
        'threshold_values': [0.05, 0.10, 0.15, 0.20],
        'threshold_seeds': [11, 22, 33],
        'threshold_epochs': 15,
    }

    experiment_specs = [
        {'name': 'Baseline', 'use_input_mask': False, 'use_capfg': False, 'use_mask_loss': False},
        {'name': 'MaskOnly', 'use_input_mask': True, 'use_capfg': False, 'use_mask_loss': False},
        {'name': 'CapFGOnly', 'use_input_mask': False, 'use_capfg': True, 'use_mask_loss': True},
        {'name': 'Full_CapFG', 'use_input_mask': True, 'use_capfg': True, 'use_mask_loss': True},
    ]

    # --------------------------------------------------------------
    # CIFAR-10 ablation
    # --------------------------------------------------------------
    print("Loading CIFAR-10...")
    train_loader, val_loader, test_loader = load_cifar10(batch_size=config['batch_size'])

    cifar_models, clean_df, history_df = train_ablation_on_dataset(
        dataset_name='CIFAR10', train_loader=train_loader, val_loader=val_loader,
        test_loader=test_loader, config=config, experiment_specs=experiment_specs,
        classes=10, output_prefix='cifar10_30epoch_tuned', save_models=True
    )
    print("\n=== CIFAR-10 Ablation Results ===")
    print(clean_df)

    baseline_model = cifar_models['Baseline']
    full_model = cifar_models['Full_CapFG']
    baseline_test_acc = float(clean_df.loc[clean_df['model'] == 'Baseline', 'test_acc'].iloc[0])
    full_test_acc = float(clean_df.loc[clean_df['model'] == 'Full_CapFG', 'test_acc'].iloc[0])

    # Routing metrics
    print("\n=== Routing Entropy and Agreement ===")
    routing_rows = []
    for label, model, apply_gate in [
        ('Baseline', baseline_model, True),
        ('Full_before_gate', full_model, False),
        ('Full_after_gate', full_model, True),
    ]:
        rm = compute_routing_metrics(model, test_loader, device, apply_capfg=apply_gate)
        routing_rows.append({'dataset': 'CIFAR10', 'model': label, **rm})
    routing_df = pd.DataFrame(routing_rows)
    print(routing_df)

    # Shortcut diagnostic
    print("\n=== Shortcut Diagnostic ===")
    shortcut = run_shortcut_diagnostic(
        baseline_model, full_model, test_loader, device,
        baseline_orig_acc=baseline_test_acc, full_orig_acc=full_test_acc
    )
    shortcut_df = pd.DataFrame([{'dataset': 'CIFAR10', **shortcut}])
    print(shortcut_df)

    # Noise robustness
    print("\n=== Noise Robustness ===")
    model_tuples = [(s['name'], cifar_models[s['name']], s['use_mask_loss']) for s in experiment_specs]
    noise_long_df, noise_wide_df = evaluate_noise_robustness(
        model_tuples, load_cifar10_corrupted_test, config, noise_levels=(0.0, 0.1, 0.2, 0.3)
    )
    print(noise_wide_df)

    # Computational cost
    print("\n=== Computational Cost ===")
    cost_rows = []
    for spec in experiment_specs:
        cost_rows.append({'dataset': 'CIFAR10', 'model': spec['name'],
                          **measure_cost(cifar_models[spec['name']], (3,32,32), batch_size=config['batch_size'])})
    cost_df = pd.DataFrame(cost_rows)
    base_params = int(cost_df.loc[cost_df['model']=='Baseline','parameters'].iloc[0])
    base_time = float(cost_df.loc[cost_df['model']=='Baseline','inference_ms_per_image'].iloc[0])
    cost_df['added_parameters_vs_baseline'] = cost_df['parameters'] - base_params
    cost_df['added_parameters_M_vs_baseline'] = cost_df['added_parameters_vs_baseline'] / 1e6
    cost_df['inference_overhead_pct_vs_baseline'] = ((cost_df['inference_ms_per_image'] / base_time) - 1) * 100
    print(cost_df)

    # Per-class metrics
    print("\n=== Per-class Metrics ===")
    classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
    base_prec, base_rec, base_f1, base_sup = compute_per_class_metrics(baseline_model, test_loader, device)
    full_prec, full_rec, full_f1, full_sup = compute_per_class_metrics(full_model, test_loader, device)
    per_class_df = pd.DataFrame({
        'dataset': 'CIFAR10', 'class': classes, 'support': base_sup,
        'baseline_precision': base_prec, 'baseline_recall': base_rec, 'baseline_f1': base_f1,
        'full_precision': full_prec, 'full_recall': full_rec, 'full_f1': full_f1,
        'delta_f1': full_f1 - base_f1,
    })
    print(per_class_df)

    # Training dynamics
    print("\n=== Training Dynamics ===")
    training_summary_df = summarize_training_dynamics(history_df)
    print(training_summary_df)


    # Representative-run confusion matrices and training curves
    print("\n=== Representative Confusion Matrices and Training Curves ===")
    class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

    cm_base, cm_full = save_confusion_matrix_figure(
        baseline_model, full_model, test_loader, class_names,
        out_png='cifar10_confusion_matrices.png'
    )

    save_training_dynamics_figure(
        history_df,
        out_png='cifar10_training_dynamics.png'
    )

    # Macro metrics for representative run
    macro_rows = []
    for name, model in [('Baseline', baseline_model), ('Full_CapFG', full_model)]:
        macro_rows.append({'model': name, **compute_macro_metrics(model, test_loader, device)})
    macro_metrics_df = pd.DataFrame(macro_rows)
    print("\n=== Representative Macro Metrics ===")
    print(macro_metrics_df)

    # Threshold sensitivity
    threshold_runs_df = pd.DataFrame()
    threshold_summary_df = pd.DataFrame()
    if config.get('run_threshold_sensitivity', False):
        print("\n=== Threshold Sensitivity ===")
        threshold_runs_df, threshold_summary_df = run_threshold_sensitivity(
            config=config,
            thresholds=config.get('threshold_values', [0.05, 0.10, 0.15, 0.20]),
            seeds=config.get('threshold_seeds', [11, 22, 33]),
            epochs=config.get('threshold_epochs', 15)
        )
        print(threshold_summary_df)

    # --------------------------------------------------------------
    # Oxford-IIIT Pets ablation and Dice
    # --------------------------------------------------------------
    pets_clean_df = pd.DataFrame()
    pets_dice_df = pd.DataFrame()
    if config['run_pets_ablation']:
        print("\nLoading Oxford-IIIT Pets...")
        pets_train, pets_val, pets_test, pets_dice_loader = load_oxford_pets(batch_size=config['pets_batch_size'])
        pets_config = config.copy()
        pets_config['batch_size'] = config['pets_batch_size']
        pets_config['classes'] = 37
        pets_config['lr'] = 0.0005
        pets_config['epochs'] = 50

        pets_models, pets_clean_df, pets_history_df = train_ablation_on_dataset(
            dataset_name='OxfordIIITPets', train_loader=pets_train, val_loader=pets_val,
            test_loader=pets_test, config=pets_config, experiment_specs=experiment_specs,
            classes=37, output_prefix='pets_30epoch_tuned', save_models=True
        )
        print("\n=== Oxford-IIIT Pets Classification Results ===")
        print(pets_clean_df)

        dice_rows = []
        for spec in experiment_specs:
            if spec['use_capfg']:
                d = evaluate_capfg_dice(pets_models[spec['name']], pets_dice_loader, device, threshold=0.5)
                dice_rows.append({'dataset': 'OxfordIIITPets', 'model': spec['name'], **d})
            else:
                dice_rows.append({'dataset': 'OxfordIIITPets', 'model': spec['name'],
                                  'mean_dice': np.nan, 'std_dice': np.nan, 'n_images': 0})
        pets_dice_df = pd.DataFrame(dice_rows)
        print("\n=== Oxford-IIIT Pets Dice Scores (Learned Masks) ===")
        print(pets_dice_df)

    # --------------------------------------------------------------
    # Repeated-seed statistical validation (10 seeds, 30 epochs each)
    # --------------------------------------------------------------
    repeated_runs_df = pd.DataFrame()
    statistical_summary_df = pd.DataFrame()
    inferential_statistics_df = pd.DataFrame()

    if config.get('run_statistical_validation', False):
        print("\n=== Running Statistical Validation (10 seeds, 30 epochs each) ===")
        stat_config = config.copy()
        stat_config['epochs'] = config.get('statistical_epochs', 30)
        repeated_runs_df, statistical_summary_df, inferential_statistics_df = run_repeated_seed_statistics(
            config=stat_config,
            seeds=config.get('statistical_seeds', [11, 22, 33, 44, 55, 66, 77, 88, 99, 101]),
            split_seed=config.get('statistical_split_seed', 42)
        )
        # Print to console
        print("\n=== Descriptive Statistical Summary ===")
        print(statistical_summary_df)
        print("\n=== Inferential Statistics (paired t-test, Wilcoxon, Cohen's dz) ===")
        print(inferential_statistics_df)

    # --------------------------------------------------------------
    # Save all outputs
    # --------------------------------------------------------------
    clean_df.to_csv('cifar10_ablation_results.csv', index=False)
    routing_df.to_csv('cifar10_routing_metrics.csv', index=False)
    shortcut_df.to_csv('cifar10_shortcut_diagnostic.csv', index=False)
    noise_wide_df.to_csv('cifar10_noise_robustness.csv', index=False)
    cost_df.to_csv('cifar10_computational_cost.csv', index=False)
    per_class_df.to_csv('cifar10_per_class_metrics.csv', index=False)
    training_summary_df.to_csv('cifar10_training_dynamics.csv', index=False)

    macro_metrics_df.to_csv('cifar10_macro_metrics.csv', index=False)
    history_df.to_csv('cifar10_training_history_representative.csv', index=False)


    if config['run_pets_ablation']:
        pets_clean_df.to_csv('pets_classification_results.csv', index=False)
        pets_dice_df.to_csv('pets_dice_scores.csv', index=False)

    # Compact summary
    summary = {
        'cifar_baseline_acc': baseline_test_acc,
        'cifar_full_acc': full_test_acc,
        'cifar_gain': full_test_acc - baseline_test_acc,
        'added_params_M': float(cost_df.loc[cost_df['model']=='Full_CapFG','added_parameters_M_vs_baseline'].iloc[0]),
        'inference_overhead_pct': float(cost_df.loc[cost_df['model']=='Full_CapFG','inference_overhead_pct_vs_baseline'].iloc[0]),
    }
    if config['run_pets_ablation'] and not pets_dice_df.empty:
        summary['pets_full_dice'] = float(pets_dice_df.loc[pets_dice_df['model']=='Full_CapFG','mean_dice'].iloc[0])
    pd.DataFrame([summary]).to_csv('summary_metrics.csv', index=False)


    # Consolidated workbook containing all tabular outputs
    result_tables = {
        'CIFAR10_Ablation': clean_df,
        'Routing_Metrics': routing_df,
        'Shortcut_Diagnostic': shortcut_df,
        'Noise_Robustness': noise_wide_df,
        'Computational_Cost': cost_df,
        'Per_Class_Metrics': per_class_df,
        'Macro_Metrics': macro_metrics_df,
        'Training_Dynamics': training_summary_df,
        'Training_History': history_df,
        'Threshold_Runs': threshold_runs_df,
        'Threshold_Summary': threshold_summary_df,
        'Pets_Classification': pets_clean_df,
        'Pets_Dice': pets_dice_df,
        'Repeated_Seed_Runs': repeated_runs_df,
        'Statistical_Summary': statistical_summary_df,
        'Inferential_Stats': inferential_statistics_df,
    }
    save_all_results_excel('CapFG_COMPLETE_RESULTS.xlsx', result_tables)

    print("\n✅ All analyses completed. Results saved as CSV files.")
    print("   - cifar10_ablation_results.csv")
    print("   - cifar10_routing_metrics.csv")
    print("   - cifar10_shortcut_diagnostic.csv")
    print("   - cifar10_noise_robustness.csv")
    print("   - cifar10_computational_cost.csv")
    print("   - cifar10_per_class_metrics.csv")
    print("   - cifar10_training_dynamics.csv")
    print("   - cifar10_training_history_representative.csv")
    print("   - cifar10_macro_metrics.csv")
    print("   - cifar10_confusion_matrix_baseline.csv")
    print("   - cifar10_confusion_matrix_full_capfg.csv")
    print("   - cifar10_confusion_matrices.png")
    print("   - cifar10_training_dynamics.png")
    if config.get("run_threshold_sensitivity", False):
        print("   - cifar10_threshold_sensitivity_runs.csv")
        print("   - cifar10_threshold_sensitivity_summary.csv")
    if config['run_pets_ablation']:
        print("   - pets_classification_results.csv")
        print("   - pets_dice_scores.csv")
    print("   - summary_metrics.csv")
    if config.get("run_statistical_validation", False):
        print("   - cifar10_repeated_seed_runs.csv")
        print("   - cifar10_paired_seed_accuracies.csv")
        print("   - cifar10_statistical_summary.csv")
        print("   - cifar10_inferential_statistics.csv")
    print("   - CapFG_COMPLETE_RESULTS.xlsx")

if __name__ == '__main__':
    main()
# Out:
# Using device: cuda
# Loading CIFAR-10...
# 100%|██████████| 170M/170M [36:31<00:00, 77.8kB/s]
# --- [CIFAR10] Training Baseline for 30 epochs ---
#   CIFAR10_Baseline | Epoch 01/30 | train_loss=0.5689 | val_loss=0.4770 | val_acc=0.4264 | best=0.4264 @ epoch 1
#   CIFAR10_Baseline | Epoch 02/30 | train_loss=0.4733 | val_loss=0.4429 | val_acc=0.4828 | best=0.4828 @ epoch 2
#   CIFAR10_Baseline | Epoch 03/30 | train_loss=0.4405 | val_loss=0.4074 | val_acc=0.5256 | best=0.5256 @ epoch 3
#   CIFAR10_Baseline | Epoch 04/30 | train_loss=0.4150 | val_loss=0.4200 | val_acc=0.5448 | best=0.5448 @ epoch 4
#   CIFAR10_Baseline | Epoch 05/30 | train_loss=0.3936 | val_loss=0.3769 | val_acc=0.5650 | best=0.5650 @ epoch 5
#   CIFAR10_Baseline | Epoch 06/30 | train_loss=0.3784 | val_loss=0.3655 | val_acc=0.5858 | best=0.5858 @ epoch 6
#   CIFAR10_Baseline | Epoch 07/30 | train_loss=0.3665 | val_loss=0.3591 | val_acc=0.5914 | best=0.5914 @ epoch 7
#   CIFAR10_Baseline | Epoch 08/30 | train_loss=0.3563 | val_loss=0.3535 | val_acc=0.6020 | best=0.6020 @ epoch 8
#   CIFAR10_Baseline | Epoch 09/30 | train_loss=0.3486 | val_loss=0.3422 | val_acc=0.5994 | best=0.6020 @ epoch 8
#   CIFAR10_Baseline | Epoch 10/30 | train_loss=0.3410 | val_loss=0.3337 | val_acc=0.6262 | best=0.6262 @ epoch 10
#   CIFAR10_Baseline | Epoch 11/30 | train_loss=0.3342 | val_loss=0.3279 | val_acc=0.6358 | best=0.6358 @ epoch 11
#   CIFAR10_Baseline | Epoch 12/30 | train_loss=0.3282 | val_loss=0.3242 | val_acc=0.6290 | best=0.6358 @ epoch 11
#   CIFAR10_Baseline | Epoch 13/30 | train_loss=0.3228 | val_loss=0.3129 | val_acc=0.6484 | best=0.6484 @ epoch 13
#   CIFAR10_Baseline | Epoch 14/30 | train_loss=0.3183 | val_loss=0.3118 | val_acc=0.6446 | best=0.6484 @ epoch 13
#   CIFAR10_Baseline | Epoch 15/30 | train_loss=0.3130 | val_loss=0.3092 | val_acc=0.6602 | best=0.6602 @ epoch 15
#   CIFAR10_Baseline | Epoch 16/30 | train_loss=0.3087 | val_loss=0.3032 | val_acc=0.6652 | best=0.6652 @ epoch 16
#   CIFAR10_Baseline | Epoch 17/30 | train_loss=0.3051 | val_loss=0.2995 | val_acc=0.6696 | best=0.6696 @ epoch 17
#   CIFAR10_Baseline | Epoch 18/30 | train_loss=0.3009 | val_loss=0.2971 | val_acc=0.6694 | best=0.6696 @ epoch 17
#   CIFAR10_Baseline | Epoch 19/30 | train_loss=0.2981 | val_loss=0.2943 | val_acc=0.6732 | best=0.6732 @ epoch 19
#   CIFAR10_Baseline | Epoch 20/30 | train_loss=0.2948 | val_loss=0.2940 | val_acc=0.6774 | best=0.6774 @ epoch 20
#   CIFAR10_Baseline | Epoch 21/30 | train_loss=0.2913 | val_loss=0.2913 | val_acc=0.6784 | best=0.6784 @ epoch 21
#   CIFAR10_Baseline | Epoch 22/30 | train_loss=0.2896 | val_loss=0.2871 | val_acc=0.6858 | best=0.6858 @ epoch 22
#   CIFAR10_Baseline | Epoch 23/30 | train_loss=0.2871 | val_loss=0.2888 | val_acc=0.6824 | best=0.6858 @ epoch 22
#   CIFAR10_Baseline | Epoch 24/30 | train_loss=0.2853 | val_loss=0.2847 | val_acc=0.6878 | best=0.6878 @ epoch 24
#   CIFAR10_Baseline | Epoch 25/30 | train_loss=0.2833 | val_loss=0.2812 | val_acc=0.6974 | best=0.6974 @ epoch 25
#   CIFAR10_Baseline | Epoch 26/30 | train_loss=0.2814 | val_loss=0.2801 | val_acc=0.6934 | best=0.6974 @ epoch 25
#   CIFAR10_Baseline | Epoch 27/30 | train_loss=0.2792 | val_loss=0.2806 | val_acc=0.6932 | best=0.6974 @ epoch 25
#   CIFAR10_Baseline | Epoch 28/30 | train_loss=0.2785 | val_loss=0.2785 | val_acc=0.6980 | best=0.6980 @ epoch 28
#   CIFAR10_Baseline | Epoch 29/30 | train_loss=0.2769 | val_loss=0.2784 | val_acc=0.6966 | best=0.6980 @ epoch 28
#   CIFAR10_Baseline | Epoch 30/30 | train_loss=0.2752 | val_loss=0.2768 | val_acc=0.6982 | best=0.6982 @ epoch 30
#
# --- [CIFAR10] Training MaskOnly for 30 epochs ---
#   CIFAR10_MaskOnly | Epoch 01/30 | train_loss=0.5613 | val_loss=0.4785 | val_acc=0.4186 | best=0.4186 @ epoch 1
#   CIFAR10_MaskOnly | Epoch 02/30 | train_loss=0.4772 | val_loss=0.4415 | val_acc=0.4684 | best=0.4684 @ epoch 2
#   CIFAR10_MaskOnly | Epoch 03/30 | train_loss=0.4466 | val_loss=0.4304 | val_acc=0.4944 | best=0.4944 @ epoch 3
#   CIFAR10_MaskOnly | Epoch 04/30 | train_loss=0.4255 | val_loss=0.4068 | val_acc=0.5250 | best=0.5250 @ epoch 4
#   CIFAR10_MaskOnly | Epoch 05/30 | train_loss=0.4043 | val_loss=0.3862 | val_acc=0.5480 | best=0.5480 @ epoch 5
#   CIFAR10_MaskOnly | Epoch 06/30 | train_loss=0.3896 | val_loss=0.3801 | val_acc=0.5448 | best=0.5480 @ epoch 5
#   CIFAR10_MaskOnly | Epoch 07/30 | train_loss=0.3768 | val_loss=0.3629 | val_acc=0.5850 | best=0.5850 @ epoch 7
#   CIFAR10_MaskOnly | Epoch 08/30 | train_loss=0.3647 | val_loss=0.3552 | val_acc=0.6000 | best=0.6000 @ epoch 8
#   CIFAR10_MaskOnly | Epoch 09/30 | train_loss=0.3548 | val_loss=0.3413 | val_acc=0.6102 | best=0.6102 @ epoch 9
#   CIFAR10_MaskOnly | Epoch 10/30 | train_loss=0.3468 | val_loss=0.3324 | val_acc=0.6282 | best=0.6282 @ epoch 10
#   CIFAR10_MaskOnly | Epoch 11/30 | train_loss=0.3391 | val_loss=0.3247 | val_acc=0.6378 | best=0.6378 @ epoch 11
#   CIFAR10_MaskOnly | Epoch 12/30 | train_loss=0.3328 | val_loss=0.3272 | val_acc=0.6332 | best=0.6378 @ epoch 11
#   CIFAR10_MaskOnly | Epoch 13/30 | train_loss=0.3261 | val_loss=0.3221 | val_acc=0.6292 | best=0.6378 @ epoch 11
#   CIFAR10_MaskOnly | Epoch 14/30 | train_loss=0.3209 | val_loss=0.3113 | val_acc=0.6490 | best=0.6490 @ epoch 14
#   CIFAR10_MaskOnly | Epoch 15/30 | train_loss=0.3168 | val_loss=0.3109 | val_acc=0.6472 | best=0.6490 @ epoch 14
#   CIFAR10_MaskOnly | Epoch 16/30 | train_loss=0.3128 | val_loss=0.3083 | val_acc=0.6544 | best=0.6544 @ epoch 16
#   CIFAR10_MaskOnly | Epoch 17/30 | train_loss=0.3082 | val_loss=0.3022 | val_acc=0.6684 | best=0.6684 @ epoch 17
#   CIFAR10_MaskOnly | Epoch 18/30 | train_loss=0.3047 | val_loss=0.3021 | val_acc=0.6718 | best=0.6718 @ epoch 18
#   CIFAR10_MaskOnly | Epoch 19/30 | train_loss=0.3013 | val_loss=0.2979 | val_acc=0.6678 | best=0.6718 @ epoch 18
#   CIFAR10_MaskOnly | Epoch 20/30 | train_loss=0.2988 | val_loss=0.2940 | val_acc=0.6726 | best=0.6726 @ epoch 20
#   CIFAR10_MaskOnly | Epoch 21/30 | train_loss=0.2958 | val_loss=0.2974 | val_acc=0.6610 | best=0.6726 @ epoch 20
#   CIFAR10_MaskOnly | Epoch 22/30 | train_loss=0.2932 | val_loss=0.2900 | val_acc=0.6802 | best=0.6802 @ epoch 22
#   CIFAR10_MaskOnly | Epoch 23/30 | train_loss=0.2904 | val_loss=0.2891 | val_acc=0.6830 | best=0.6830 @ epoch 23
#   CIFAR10_MaskOnly | Epoch 24/30 | train_loss=0.2883 | val_loss=0.2862 | val_acc=0.6874 | best=0.6874 @ epoch 24
#   CIFAR10_MaskOnly | Epoch 25/30 | train_loss=0.2864 | val_loss=0.2855 | val_acc=0.6810 | best=0.6874 @ epoch 24
#   CIFAR10_MaskOnly | Epoch 26/30 | train_loss=0.2844 | val_loss=0.2846 | val_acc=0.6882 | best=0.6882 @ epoch 26
#   CIFAR10_MaskOnly | Epoch 27/30 | train_loss=0.2825 | val_loss=0.2831 | val_acc=0.6886 | best=0.6886 @ epoch 27
#   CIFAR10_MaskOnly | Epoch 28/30 | train_loss=0.2806 | val_loss=0.2804 | val_acc=0.6910 | best=0.6910 @ epoch 28
#   CIFAR10_MaskOnly | Epoch 29/30 | train_loss=0.2789 | val_loss=0.2796 | val_acc=0.6914 | best=0.6914 @ epoch 29
#   CIFAR10_MaskOnly | Epoch 30/30 | train_loss=0.2782 | val_loss=0.2794 | val_acc=0.6956 | best=0.6956 @ epoch 30
#
# --- [CIFAR10] Training CapFGOnly for 30 epochs ---
#   CIFAR10_CapFGOnly | Epoch 01/30 | train_loss=0.5717 | val_loss=0.4806 | val_acc=0.4096 | best=0.4096 @ epoch 1
#   CIFAR10_CapFGOnly | Epoch 02/30 | train_loss=0.4783 | val_loss=0.4425 | val_acc=0.4628 | best=0.4628 @ epoch 2
#   CIFAR10_CapFGOnly | Epoch 03/30 | train_loss=0.4396 | val_loss=0.4093 | val_acc=0.5146 | best=0.5146 @ epoch 3
#   CIFAR10_CapFGOnly | Epoch 04/30 | train_loss=0.4134 | val_loss=0.3865 | val_acc=0.5522 | best=0.5522 @ epoch 4
#   CIFAR10_CapFGOnly | Epoch 05/30 | train_loss=0.3908 | val_loss=0.3784 | val_acc=0.5592 | best=0.5592 @ epoch 5
#   CIFAR10_CapFGOnly | Epoch 06/30 | train_loss=0.3738 | val_loss=0.3613 | val_acc=0.5694 | best=0.5694 @ epoch 6
#   CIFAR10_CapFGOnly | Epoch 07/30 | train_loss=0.3609 | val_loss=0.3488 | val_acc=0.5892 | best=0.5892 @ epoch 7
#   CIFAR10_CapFGOnly | Epoch 08/30 | train_loss=0.3489 | val_loss=0.3438 | val_acc=0.6078 | best=0.6078 @ epoch 8
#   CIFAR10_CapFGOnly | Epoch 09/30 | train_loss=0.3395 | val_loss=0.3337 | val_acc=0.6100 | best=0.6100 @ epoch 9
#   CIFAR10_CapFGOnly | Epoch 10/30 | train_loss=0.3296 | val_loss=0.3201 | val_acc=0.6356 | best=0.6356 @ epoch 10
#   CIFAR10_CapFGOnly | Epoch 11/30 | train_loss=0.3217 | val_loss=0.3223 | val_acc=0.6314 | best=0.6356 @ epoch 10
#   CIFAR10_CapFGOnly | Epoch 12/30 | train_loss=0.3139 | val_loss=0.3066 | val_acc=0.6472 | best=0.6472 @ epoch 12
#   CIFAR10_CapFGOnly | Epoch 13/30 | train_loss=0.3077 | val_loss=0.3015 | val_acc=0.6568 | best=0.6568 @ epoch 13
#   CIFAR10_CapFGOnly | Epoch 14/30 | train_loss=0.3015 | val_loss=0.3041 | val_acc=0.6412 | best=0.6568 @ epoch 13
#   CIFAR10_CapFGOnly | Epoch 15/30 | train_loss=0.2954 | val_loss=0.3089 | val_acc=0.6408 | best=0.6568 @ epoch 13
#   CIFAR10_CapFGOnly | Epoch 16/30 | train_loss=0.2899 | val_loss=0.2879 | val_acc=0.6714 | best=0.6714 @ epoch 16
#   CIFAR10_CapFGOnly | Epoch 17/30 | train_loss=0.2865 | val_loss=0.2835 | val_acc=0.6808 | best=0.6808 @ epoch 17
#   CIFAR10_CapFGOnly | Epoch 18/30 | train_loss=0.2815 | val_loss=0.2834 | val_acc=0.6840 | best=0.6840 @ epoch 18
#   CIFAR10_CapFGOnly | Epoch 19/30 | train_loss=0.2777 | val_loss=0.2789 | val_acc=0.6842 | best=0.6842 @ epoch 19
#   CIFAR10_CapFGOnly | Epoch 20/30 | train_loss=0.2736 | val_loss=0.2772 | val_acc=0.6906 | best=0.6906 @ epoch 20
#   CIFAR10_CapFGOnly | Epoch 21/30 | train_loss=0.2710 | val_loss=0.2749 | val_acc=0.6914 | best=0.6914 @ epoch 21
#   CIFAR10_CapFGOnly | Epoch 22/30 | train_loss=0.2689 | val_loss=0.2709 | val_acc=0.7014 | best=0.7014 @ epoch 22
#   CIFAR10_CapFGOnly | Epoch 23/30 | train_loss=0.2650 | val_loss=0.2712 | val_acc=0.6944 | best=0.7014 @ epoch 22
#   CIFAR10_CapFGOnly | Epoch 24/30 | train_loss=0.2639 | val_loss=0.2675 | val_acc=0.7054 | best=0.7054 @ epoch 24
#   CIFAR10_CapFGOnly | Epoch 25/30 | train_loss=0.2608 | val_loss=0.2718 | val_acc=0.6946 | best=0.7054 @ epoch 24
#   CIFAR10_CapFGOnly | Epoch 26/30 | train_loss=0.2584 | val_loss=0.2649 | val_acc=0.7104 | best=0.7104 @ epoch 26
#   CIFAR10_CapFGOnly | Epoch 27/30 | train_loss=0.2570 | val_loss=0.2640 | val_acc=0.7016 | best=0.7104 @ epoch 26
#   CIFAR10_CapFGOnly | Epoch 28/30 | train_loss=0.2555 | val_loss=0.2700 | val_acc=0.6980 | best=0.7104 @ epoch 26
#   CIFAR10_CapFGOnly | Epoch 29/30 | train_loss=0.2541 | val_loss=0.2597 | val_acc=0.7104 | best=0.7104 @ epoch 26
#   CIFAR10_CapFGOnly | Epoch 30/30 | train_loss=0.2518 | val_loss=0.2631 | val_acc=0.7034 | best=0.7104 @ epoch 26
#
# --- [CIFAR10] Training Full_CapFG for 30 epochs ---
#   CIFAR10_Full_CapFG | Epoch 01/30 | train_loss=0.5618 | val_loss=0.4903 | val_acc=0.3852 | best=0.3852 @ epoch 1
#   CIFAR10_Full_CapFG | Epoch 02/30 | train_loss=0.4764 | val_loss=0.4384 | val_acc=0.4772 | best=0.4772 @ epoch 2
#   CIFAR10_Full_CapFG | Epoch 03/30 | train_loss=0.4430 | val_loss=0.4115 | val_acc=0.5060 | best=0.5060 @ epoch 3
#   CIFAR10_Full_CapFG | Epoch 04/30 | train_loss=0.4160 | val_loss=0.3934 | val_acc=0.5358 | best=0.5358 @ epoch 4
#   CIFAR10_Full_CapFG | Epoch 05/30 | train_loss=0.3935 | val_loss=0.3783 | val_acc=0.5666 | best=0.5666 @ epoch 5
#   CIFAR10_Full_CapFG | Epoch 06/30 | train_loss=0.3757 | val_loss=0.3612 | val_acc=0.5696 | best=0.5696 @ epoch 6
#   CIFAR10_Full_CapFG | Epoch 07/30 | train_loss=0.3616 | val_loss=0.3592 | val_acc=0.5832 | best=0.5832 @ epoch 7
#   CIFAR10_Full_CapFG | Epoch 08/30 | train_loss=0.3484 | val_loss=0.3403 | val_acc=0.6074 | best=0.6074 @ epoch 8
#   CIFAR10_Full_CapFG | Epoch 09/30 | train_loss=0.3367 | val_loss=0.3367 | val_acc=0.6068 | best=0.6074 @ epoch 8
#   CIFAR10_Full_CapFG | Epoch 10/30 | train_loss=0.3290 | val_loss=0.3191 | val_acc=0.6366 | best=0.6366 @ epoch 10
#   CIFAR10_Full_CapFG | Epoch 11/30 | train_loss=0.3219 | val_loss=0.3122 | val_acc=0.6420 | best=0.6420 @ epoch 11
#   CIFAR10_Full_CapFG | Epoch 12/30 | train_loss=0.3119 | val_loss=0.3048 | val_acc=0.6534 | best=0.6534 @ epoch 12
#   CIFAR10_Full_CapFG | Epoch 13/30 | train_loss=0.3052 | val_loss=0.3051 | val_acc=0.6516 | best=0.6534 @ epoch 12
#   CIFAR10_Full_CapFG | Epoch 14/30 | train_loss=0.3007 | val_loss=0.3008 | val_acc=0.6562 | best=0.6562 @ epoch 14
#   CIFAR10_Full_CapFG | Epoch 15/30 | train_loss=0.2939 | val_loss=0.3005 | val_acc=0.6568 | best=0.6568 @ epoch 15
#   CIFAR10_Full_CapFG | Epoch 16/30 | train_loss=0.2903 | val_loss=0.2911 | val_acc=0.6696 | best=0.6696 @ epoch 16
#   CIFAR10_Full_CapFG | Epoch 17/30 | train_loss=0.2848 | val_loss=0.2867 | val_acc=0.6772 | best=0.6772 @ epoch 17
#   CIFAR10_Full_CapFG | Epoch 18/30 | train_loss=0.2813 | val_loss=0.2825 | val_acc=0.6812 | best=0.6812 @ epoch 18
#   CIFAR10_Full_CapFG | Epoch 19/30 | train_loss=0.2761 | val_loss=0.2797 | val_acc=0.6886 | best=0.6886 @ epoch 19
#   CIFAR10_Full_CapFG | Epoch 20/30 | train_loss=0.2737 | val_loss=0.2821 | val_acc=0.6716 | best=0.6886 @ epoch 19
#   CIFAR10_Full_CapFG | Epoch 21/30 | train_loss=0.2703 | val_loss=0.2736 | val_acc=0.6918 | best=0.6918 @ epoch 21
#   CIFAR10_Full_CapFG | Epoch 22/30 | train_loss=0.2683 | val_loss=0.2735 | val_acc=0.6990 | best=0.6990 @ epoch 22
#   CIFAR10_Full_CapFG | Epoch 23/30 | train_loss=0.2651 | val_loss=0.2715 | val_acc=0.6938 | best=0.6990 @ epoch 22
#   CIFAR10_Full_CapFG | Epoch 24/30 | train_loss=0.2625 | val_loss=0.2691 | val_acc=0.6938 | best=0.6990 @ epoch 22
#   CIFAR10_Full_CapFG | Epoch 25/30 | train_loss=0.2610 | val_loss=0.2711 | val_acc=0.7008 | best=0.7008 @ epoch 25
#   CIFAR10_Full_CapFG | Epoch 26/30 | train_loss=0.2580 | val_loss=0.2681 | val_acc=0.6952 | best=0.7008 @ epoch 25
#   CIFAR10_Full_CapFG | Epoch 27/30 | train_loss=0.2565 | val_loss=0.2662 | val_acc=0.6990 | best=0.7008 @ epoch 25
#   CIFAR10_Full_CapFG | Epoch 28/30 | train_loss=0.2554 | val_loss=0.2639 | val_acc=0.7068 | best=0.7068 @ epoch 28
#   CIFAR10_Full_CapFG | Epoch 29/30 | train_loss=0.2535 | val_loss=0.2633 | val_acc=0.7056 | best=0.7068 @ epoch 28
#   CIFAR10_Full_CapFG | Epoch 30/30 | train_loss=0.2523 | val_loss=0.2629 | val_acc=0.7056 | best=0.7068 @ epoch 28
#
# === CIFAR-10 Ablation Results ===
#    dataset       model  best_val_acc  best_epoch  test_loss  test_acc
# 0  CIFAR10    Baseline        0.6982          30   0.277771    0.6996
# 1  CIFAR10    MaskOnly        0.6956          30   0.279543    0.7012
# 2  CIFAR10   CapFGOnly        0.7104          26   0.265379    0.7097
# 3  CIFAR10  Full_CapFG        0.7068          28   0.263297    0.7119
#
# === Routing Entropy and Agreement ===
#    dataset             model  weighted_agreement_mean  weighted_agreement_std  \
# 0  CIFAR10          Baseline                 0.000875                0.000261
# 1  CIFAR10  Full_before_gate                 0.003331                0.001307
# 2  CIFAR10   Full_after_gate                 0.000975                0.000355
#
#    mean_dot_agreement_mean  mean_dot_agreement_std  routing_entropy_mean  \
# 0                 0.000634                0.000139              2.302398
# 1                 0.002211                0.000736              2.301753
# 2                 0.000689                0.000171              2.302345
#
#    routing_entropy_std
# 0             0.000140
# 1             0.000459
# 2             0.000211
#
# === Shortcut Diagnostic ===
#    dataset  baseline_shifted_acc  full_shifted_acc  baseline_drop  full_drop
# 0  CIFAR10                 0.208            0.1924         0.4916     0.5195
#
# === Noise Robustness ===
# model  noise_std  Baseline  CapFGOnly  Full_CapFG  MaskOnly  \
# 0            0.0    0.6996     0.7097      0.7119    0.7012
# 1            0.1    0.6458     0.6435      0.6561    0.6430
# 2            0.2    0.4591     0.4453      0.4689    0.4114
# 3            0.3    0.3038     0.2773      0.2774    0.2295
#
# model  Full_minus_Baseline
# 0                   0.0123
# 1                   0.0103
# 2                   0.0098
# 3                  -0.0264
#
# === Computational Cost ===
# FLOPs not computed for CapsuleNetAblation: No module named 'thop'
# FLOPs not computed for CapsuleNetAblation: No module named 'thop'
# FLOPs not computed for CapsuleNetAblation: No module named 'thop'
# FLOPs not computed for CapsuleNetAblation: No module named 'thop'
#    dataset       model  parameters  trainable_parameters  parameters_M FLOPs  \
# 0  CIFAR10    Baseline    11749120              11749120     11.749120  None
# 1  CIFAR10    MaskOnly    11749120              11749120     11.749120  None
# 2  CIFAR10   CapFGOnly    11763139              11763139     11.763139  None
# 3  CIFAR10  Full_CapFG    11763139              11763139     11.763139  None
#
#    FLOPs_M  inference_ms_per_batch  inference_ms_per_image  \
# 0      NaN                4.963911                0.038781
# 1      NaN                4.947178                0.038650
# 2      NaN                5.113192                0.039947
# 3      NaN                5.123618                0.040028
#
#    added_parameters_vs_baseline  added_parameters_M_vs_baseline  \
# 0                             0                        0.000000
# 1                             0                        0.000000
# 2                         14019                        0.014019
# 3                         14019                        0.014019
#
#    inference_overhead_pct_vs_baseline
# 0                            0.000000
# 1                           -0.337077
# 2                            3.007327
# 3                            3.217364
#
# === Per-class Metrics ===
#    dataset       class  support  baseline_precision  baseline_recall  \
# 0  CIFAR10    airplane     1000            0.719016            0.760
# 1  CIFAR10  automobile     1000            0.820792            0.829
# 2  CIFAR10        bird     1000            0.647131            0.530
# 3  CIFAR10         cat     1000            0.590206            0.458
# 4  CIFAR10        deer     1000            0.605364            0.632
# 5  CIFAR10         dog     1000            0.616480            0.606
# 6  CIFAR10        frog     1000            0.698606            0.802
# 7  CIFAR10       horse     1000            0.726378            0.738
# 8  CIFAR10        ship     1000            0.828718            0.808
# 9  CIFAR10       truck     1000            0.710751            0.833
#
#    baseline_f1  full_precision  full_recall   full_f1  delta_f1
# 0     0.738940        0.757576        0.750  0.753769  0.014829
# 1     0.824876        0.872591        0.815  0.842813  0.017937
# 2     0.582738        0.687335        0.521  0.592719  0.009981
# 3     0.515766        0.571257        0.477  0.519891  0.004125
# 4     0.618395        0.627835        0.609  0.618274 -0.000121
# 5     0.611195        0.616438        0.675  0.644391  0.033196
# 6     0.746741        0.710549        0.815  0.759199  0.012458
# 7     0.732143        0.704668        0.785  0.742668  0.010525
# 8     0.818228        0.768129        0.858  0.810581 -0.007647
# 9     0.767035        0.782692        0.814  0.798039  0.031004
#
# === Training Dynamics ===
#                 model  best_val_acc  best_epoch  epochs_to_95pct_best  \
# 0    CIFAR10_Baseline        0.6982          30                    16
# 1   CIFAR10_CapFGOnly        0.7104          26                    17
# 2  CIFAR10_Full_CapFG        0.7068          28                    17
# 3    CIFAR10_MaskOnly        0.6956          30                    17
#
#    final_train_loss  final_val_loss  mean_epoch_time_sec  \
# 0          0.275218        0.276794             7.378315
# 1          0.251827        0.263060             7.334177
# 2          0.252262        0.262879             7.388053
# 3          0.278248        0.279391             7.331300
#
#    val_acc_variance_last5
# 0                0.000006
# 1                0.000030
# 2                0.000026
# 3                0.000009
#
# === Representative Confusion Matrices and Training Curves ===
#
# === Representative Macro Metrics ===
#         model  accuracy  macro_precision  macro_recall  macro_f1
# 0    Baseline    0.6996         0.696344        0.6996  0.695606
# 1  Full_CapFG    0.7119         0.709907        0.7119  0.708234
#
# === Threshold Sensitivity ===
#   THR_0.05_11_MaskOnly | Epoch 01/15 | train_loss=0.5587 | val_loss=0.4850 | val_acc=0.4168 | best=0.4168 @ epoch 1
#   THR_0.05_11_MaskOnly | Epoch 02/15 | train_loss=0.4758 | val_loss=0.4428 | val_acc=0.4534 | best=0.4534 @ epoch 2
#   THR_0.05_11_MaskOnly | Epoch 03/15 | train_loss=0.4447 | val_loss=0.4240 | val_acc=0.4870 | best=0.4870 @ epoch 3
#   THR_0.05_11_MaskOnly | Epoch 04/15 | train_loss=0.4247 | val_loss=0.3987 | val_acc=0.5302 | best=0.5302 @ epoch 4
#   THR_0.05_11_MaskOnly | Epoch 05/15 | train_loss=0.4011 | val_loss=0.3897 | val_acc=0.5398 | best=0.5398 @ epoch 5
#   THR_0.05_11_MaskOnly | Epoch 06/15 | train_loss=0.3863 | val_loss=0.3743 | val_acc=0.5556 | best=0.5556 @ epoch 6
#   THR_0.05_11_MaskOnly | Epoch 07/15 | train_loss=0.3746 | val_loss=0.3647 | val_acc=0.5668 | best=0.5668 @ epoch 7
#   THR_0.05_11_MaskOnly | Epoch 08/15 | train_loss=0.3660 | val_loss=0.3551 | val_acc=0.5852 | best=0.5852 @ epoch 8
#   THR_0.05_11_MaskOnly | Epoch 09/15 | train_loss=0.3575 | val_loss=0.3459 | val_acc=0.6008 | best=0.6008 @ epoch 9
#   THR_0.05_11_MaskOnly | Epoch 10/15 | train_loss=0.3489 | val_loss=0.3363 | val_acc=0.6092 | best=0.6092 @ epoch 10
#   THR_0.05_11_MaskOnly | Epoch 11/15 | train_loss=0.3413 | val_loss=0.3366 | val_acc=0.6174 | best=0.6174 @ epoch 11
#   THR_0.05_11_MaskOnly | Epoch 12/15 | train_loss=0.3350 | val_loss=0.3217 | val_acc=0.6392 | best=0.6392 @ epoch 12
#   THR_0.05_11_MaskOnly | Epoch 13/15 | train_loss=0.3291 | val_loss=0.3202 | val_acc=0.6422 | best=0.6422 @ epoch 13
#   THR_0.05_11_MaskOnly | Epoch 14/15 | train_loss=0.3242 | val_loss=0.3138 | val_acc=0.6386 | best=0.6422 @ epoch 13
#   THR_0.05_11_MaskOnly | Epoch 15/15 | train_loss=0.3194 | val_loss=0.3107 | val_acc=0.6456 | best=0.6456 @ epoch 15
#   THR_0.05_11_Full_CapFG | Epoch 01/15 | train_loss=0.5660 | val_loss=0.4795 | val_acc=0.4186 | best=0.4186 @ epoch 1
#   THR_0.05_11_Full_CapFG | Epoch 02/15 | train_loss=0.4707 | val_loss=0.4324 | val_acc=0.4804 | best=0.4804 @ epoch 2
#   THR_0.05_11_Full_CapFG | Epoch 03/15 | train_loss=0.4340 | val_loss=0.4063 | val_acc=0.5184 | best=0.5184 @ epoch 3
#   THR_0.05_11_Full_CapFG | Epoch 04/15 | train_loss=0.4066 | val_loss=0.3939 | val_acc=0.5378 | best=0.5378 @ epoch 4
#   THR_0.05_11_Full_CapFG | Epoch 05/15 | train_loss=0.3860 | val_loss=0.3752 | val_acc=0.5672 | best=0.5672 @ epoch 5
#   THR_0.05_11_Full_CapFG | Epoch 06/15 | train_loss=0.3722 | val_loss=0.3619 | val_acc=0.5758 | best=0.5758 @ epoch 6
#   THR_0.05_11_Full_CapFG | Epoch 07/15 | train_loss=0.3596 | val_loss=0.3592 | val_acc=0.5832 | best=0.5832 @ epoch 7
#   THR_0.05_11_Full_CapFG | Epoch 08/15 | train_loss=0.3493 | val_loss=0.3353 | val_acc=0.6174 | best=0.6174 @ epoch 8
#   THR_0.05_11_Full_CapFG | Epoch 09/15 | train_loss=0.3391 | val_loss=0.3398 | val_acc=0.6028 | best=0.6174 @ epoch 8
#   THR_0.05_11_Full_CapFG | Epoch 10/15 | train_loss=0.3290 | val_loss=0.3323 | val_acc=0.6132 | best=0.6174 @ epoch 8
#   THR_0.05_11_Full_CapFG | Epoch 11/15 | train_loss=0.3233 | val_loss=0.3159 | val_acc=0.6362 | best=0.6362 @ epoch 11
#   THR_0.05_11_Full_CapFG | Epoch 12/15 | train_loss=0.3146 | val_loss=0.3226 | val_acc=0.6208 | best=0.6362 @ epoch 11
#   THR_0.05_11_Full_CapFG | Epoch 13/15 | train_loss=0.3076 | val_loss=0.3084 | val_acc=0.6484 | best=0.6484 @ epoch 13
#   THR_0.05_11_Full_CapFG | Epoch 14/15 | train_loss=0.3022 | val_loss=0.2975 | val_acc=0.6636 | best=0.6636 @ epoch 14
#   THR_0.05_11_Full_CapFG | Epoch 15/15 | train_loss=0.2968 | val_loss=0.2966 | val_acc=0.6548 | best=0.6636 @ epoch 14
#   THR_0.05_22_MaskOnly | Epoch 01/15 | train_loss=0.5574 | val_loss=0.4797 | val_acc=0.4074 | best=0.4074 @ epoch 1
#   THR_0.05_22_MaskOnly | Epoch 02/15 | train_loss=0.4739 | val_loss=0.4379 | val_acc=0.4756 | best=0.4756 @ epoch 2
#   THR_0.05_22_MaskOnly | Epoch 03/15 | train_loss=0.4393 | val_loss=0.4222 | val_acc=0.4888 | best=0.4888 @ epoch 3
#   THR_0.05_22_MaskOnly | Epoch 04/15 | train_loss=0.4165 | val_loss=0.4014 | val_acc=0.5380 | best=0.5380 @ epoch 4
#   THR_0.05_22_MaskOnly | Epoch 05/15 | train_loss=0.3982 | val_loss=0.3845 | val_acc=0.5570 | best=0.5570 @ epoch 5
#   THR_0.05_22_MaskOnly | Epoch 06/15 | train_loss=0.3836 | val_loss=0.3740 | val_acc=0.5734 | best=0.5734 @ epoch 6
#   THR_0.05_22_MaskOnly | Epoch 07/15 | train_loss=0.3746 | val_loss=0.3689 | val_acc=0.5730 | best=0.5734 @ epoch 6
#   THR_0.05_22_MaskOnly | Epoch 08/15 | train_loss=0.3641 | val_loss=0.3523 | val_acc=0.5918 | best=0.5918 @ epoch 8
#   THR_0.05_22_MaskOnly | Epoch 09/15 | train_loss=0.3546 | val_loss=0.3501 | val_acc=0.5964 | best=0.5964 @ epoch 9
#   THR_0.05_22_MaskOnly | Epoch 10/15 | train_loss=0.3480 | val_loss=0.3432 | val_acc=0.5962 | best=0.5964 @ epoch 9
#   THR_0.05_22_MaskOnly | Epoch 11/15 | train_loss=0.3412 | val_loss=0.3306 | val_acc=0.6210 | best=0.6210 @ epoch 11
#   THR_0.05_22_MaskOnly | Epoch 12/15 | train_loss=0.3358 | val_loss=0.3267 | val_acc=0.6354 | best=0.6354 @ epoch 12
#   THR_0.05_22_MaskOnly | Epoch 13/15 | train_loss=0.3308 | val_loss=0.3193 | val_acc=0.6440 | best=0.6440 @ epoch 13
#   THR_0.05_22_MaskOnly | Epoch 14/15 | train_loss=0.3249 | val_loss=0.3299 | val_acc=0.6102 | best=0.6440 @ epoch 13
#   THR_0.05_22_MaskOnly | Epoch 15/15 | train_loss=0.3217 | val_loss=0.3142 | val_acc=0.6458 | best=0.6458 @ epoch 15
#   THR_0.05_22_Full_CapFG | Epoch 01/15 | train_loss=0.5649 | val_loss=0.4773 | val_acc=0.4188 | best=0.4188 @ epoch 1
#   THR_0.05_22_Full_CapFG | Epoch 02/15 | train_loss=0.4788 | val_loss=0.4337 | val_acc=0.4826 | best=0.4826 @ epoch 2
#   THR_0.05_22_Full_CapFG | Epoch 03/15 | train_loss=0.4412 | val_loss=0.4152 | val_acc=0.5190 | best=0.5190 @ epoch 3
#   THR_0.05_22_Full_CapFG | Epoch 04/15 | train_loss=0.4158 | val_loss=0.3995 | val_acc=0.5222 | best=0.5222 @ epoch 4
#   THR_0.05_22_Full_CapFG | Epoch 05/15 | train_loss=0.3918 | val_loss=0.3717 | val_acc=0.5620 | best=0.5620 @ epoch 5
#   THR_0.05_22_Full_CapFG | Epoch 06/15 | train_loss=0.3724 | val_loss=0.3615 | val_acc=0.5922 | best=0.5922 @ epoch 6
#   THR_0.05_22_Full_CapFG | Epoch 07/15 | train_loss=0.3572 | val_loss=0.3432 | val_acc=0.6068 | best=0.6068 @ epoch 7
#   THR_0.05_22_Full_CapFG | Epoch 08/15 | train_loss=0.3455 | val_loss=0.3297 | val_acc=0.6272 | best=0.6272 @ epoch 8
#   THR_0.05_22_Full_CapFG | Epoch 09/15 | train_loss=0.3329 | val_loss=0.3275 | val_acc=0.6186 | best=0.6272 @ epoch 8
#   THR_0.05_22_Full_CapFG | Epoch 10/15 | train_loss=0.3247 | val_loss=0.3256 | val_acc=0.6206 | best=0.6272 @ epoch 8
#   THR_0.05_22_Full_CapFG | Epoch 11/15 | train_loss=0.3171 | val_loss=0.3167 | val_acc=0.6434 | best=0.6434 @ epoch 11
#   THR_0.05_22_Full_CapFG | Epoch 12/15 | train_loss=0.3097 | val_loss=0.3049 | val_acc=0.6588 | best=0.6588 @ epoch 12
#   THR_0.05_22_Full_CapFG | Epoch 13/15 | train_loss=0.3030 | val_loss=0.3072 | val_acc=0.6478 | best=0.6588 @ epoch 12
#   THR_0.05_22_Full_CapFG | Epoch 14/15 | train_loss=0.2972 | val_loss=0.2946 | val_acc=0.6686 | best=0.6686 @ epoch 14
#   THR_0.05_22_Full_CapFG | Epoch 15/15 | train_loss=0.2903 | val_loss=0.2969 | val_acc=0.6664 | best=0.6686 @ epoch 14
#   THR_0.05_33_MaskOnly | Epoch 01/15 | train_loss=0.5609 | val_loss=0.4846 | val_acc=0.4056 | best=0.4056 @ epoch 1
#   THR_0.05_33_MaskOnly | Epoch 02/15 | train_loss=0.4791 | val_loss=0.4475 | val_acc=0.4378 | best=0.4378 @ epoch 2
#   THR_0.05_33_MaskOnly | Epoch 03/15 | train_loss=0.4489 | val_loss=0.4319 | val_acc=0.4766 | best=0.4766 @ epoch 3
#   THR_0.05_33_MaskOnly | Epoch 04/15 | train_loss=0.4247 | val_loss=0.4124 | val_acc=0.5116 | best=0.5116 @ epoch 4
#   THR_0.05_33_MaskOnly | Epoch 05/15 | train_loss=0.4040 | val_loss=0.3889 | val_acc=0.5516 | best=0.5516 @ epoch 5
#   THR_0.05_33_MaskOnly | Epoch 06/15 | train_loss=0.3897 | val_loss=0.3855 | val_acc=0.5462 | best=0.5516 @ epoch 5
#   THR_0.05_33_MaskOnly | Epoch 07/15 | train_loss=0.3778 | val_loss=0.3748 | val_acc=0.5630 | best=0.5630 @ epoch 7
#   THR_0.05_33_MaskOnly | Epoch 08/15 | train_loss=0.3680 | val_loss=0.3572 | val_acc=0.5906 | best=0.5906 @ epoch 8
#   THR_0.05_33_MaskOnly | Epoch 09/15 | train_loss=0.3587 | val_loss=0.3482 | val_acc=0.5956 | best=0.5956 @ epoch 9
#   THR_0.05_33_MaskOnly | Epoch 10/15 | train_loss=0.3521 | val_loss=0.3418 | val_acc=0.6044 | best=0.6044 @ epoch 10
#   THR_0.05_33_MaskOnly | Epoch 11/15 | train_loss=0.3441 | val_loss=0.3372 | val_acc=0.5970 | best=0.6044 @ epoch 10
#   THR_0.05_33_MaskOnly | Epoch 12/15 | train_loss=0.3381 | val_loss=0.3292 | val_acc=0.6306 | best=0.6306 @ epoch 12
#   THR_0.05_33_MaskOnly | Epoch 13/15 | train_loss=0.3321 | val_loss=0.3260 | val_acc=0.6232 | best=0.6306 @ epoch 12
#   THR_0.05_33_MaskOnly | Epoch 14/15 | train_loss=0.3267 | val_loss=0.3268 | val_acc=0.6230 | best=0.6306 @ epoch 12
#   THR_0.05_33_MaskOnly | Epoch 15/15 | train_loss=0.3209 | val_loss=0.3174 | val_acc=0.6350 | best=0.6350 @ epoch 15
#   THR_0.05_33_Full_CapFG | Epoch 01/15 | train_loss=0.5679 | val_loss=0.4733 | val_acc=0.4182 | best=0.4182 @ epoch 1
#   THR_0.05_33_Full_CapFG | Epoch 02/15 | train_loss=0.4764 | val_loss=0.4359 | val_acc=0.4754 | best=0.4754 @ epoch 2
#   THR_0.05_33_Full_CapFG | Epoch 03/15 | train_loss=0.4390 | val_loss=0.4258 | val_acc=0.4764 | best=0.4764 @ epoch 3
#   THR_0.05_33_Full_CapFG | Epoch 04/15 | train_loss=0.4168 | val_loss=0.3957 | val_acc=0.5476 | best=0.5476 @ epoch 4
#   THR_0.05_33_Full_CapFG | Epoch 05/15 | train_loss=0.3926 | val_loss=0.3764 | val_acc=0.5754 | best=0.5754 @ epoch 5
#   THR_0.05_33_Full_CapFG | Epoch 06/15 | train_loss=0.3732 | val_loss=0.3720 | val_acc=0.5628 | best=0.5754 @ epoch 5
#   THR_0.05_33_Full_CapFG | Epoch 07/15 | train_loss=0.3580 | val_loss=0.3446 | val_acc=0.5998 | best=0.5998 @ epoch 7
#   THR_0.05_33_Full_CapFG | Epoch 08/15 | train_loss=0.3452 | val_loss=0.3391 | val_acc=0.6206 | best=0.6206 @ epoch 8
#   THR_0.05_33_Full_CapFG | Epoch 09/15 | train_loss=0.3340 | val_loss=0.3202 | val_acc=0.6326 | best=0.6326 @ epoch 9
#   THR_0.05_33_Full_CapFG | Epoch 10/15 | train_loss=0.3249 | val_loss=0.3240 | val_acc=0.6216 | best=0.6326 @ epoch 9
#   THR_0.05_33_Full_CapFG | Epoch 11/15 | train_loss=0.3157 | val_loss=0.3026 | val_acc=0.6562 | best=0.6562 @ epoch 11
#   THR_0.05_33_Full_CapFG | Epoch 12/15 | train_loss=0.3075 | val_loss=0.3078 | val_acc=0.6484 | best=0.6562 @ epoch 11
#   THR_0.05_33_Full_CapFG | Epoch 13/15 | train_loss=0.2999 | val_loss=0.2935 | val_acc=0.6640 | best=0.6640 @ epoch 13
#   THR_0.05_33_Full_CapFG | Epoch 14/15 | train_loss=0.2946 | val_loss=0.2956 | val_acc=0.6676 | best=0.6676 @ epoch 14
#   THR_0.05_33_Full_CapFG | Epoch 15/15 | train_loss=0.2894 | val_loss=0.2954 | val_acc=0.6628 | best=0.6676 @ epoch 14
#   THR_0.1_11_MaskOnly | Epoch 01/15 | train_loss=0.5565 | val_loss=0.4801 | val_acc=0.4128 | best=0.4128 @ epoch 1
#   THR_0.1_11_MaskOnly | Epoch 02/15 | train_loss=0.4729 | val_loss=0.4420 | val_acc=0.4596 | best=0.4596 @ epoch 2
#   THR_0.1_11_MaskOnly | Epoch 03/15 | train_loss=0.4426 | val_loss=0.4244 | val_acc=0.4848 | best=0.4848 @ epoch 3
#   THR_0.1_11_MaskOnly | Epoch 04/15 | train_loss=0.4198 | val_loss=0.3959 | val_acc=0.5322 | best=0.5322 @ epoch 4
#   THR_0.1_11_MaskOnly | Epoch 05/15 | train_loss=0.3957 | val_loss=0.3815 | val_acc=0.5508 | best=0.5508 @ epoch 5
#   THR_0.1_11_MaskOnly | Epoch 06/15 | train_loss=0.3809 | val_loss=0.3682 | val_acc=0.5744 | best=0.5744 @ epoch 6
#   THR_0.1_11_MaskOnly | Epoch 07/15 | train_loss=0.3687 | val_loss=0.3581 | val_acc=0.5806 | best=0.5806 @ epoch 7
#   THR_0.1_11_MaskOnly | Epoch 08/15 | train_loss=0.3590 | val_loss=0.3478 | val_acc=0.5978 | best=0.5978 @ epoch 8
#   THR_0.1_11_MaskOnly | Epoch 09/15 | train_loss=0.3496 | val_loss=0.3399 | val_acc=0.6154 | best=0.6154 @ epoch 9
#   THR_0.1_11_MaskOnly | Epoch 10/15 | train_loss=0.3418 | val_loss=0.3294 | val_acc=0.6200 | best=0.6200 @ epoch 10
#   THR_0.1_11_MaskOnly | Epoch 11/15 | train_loss=0.3341 | val_loss=0.3295 | val_acc=0.6354 | best=0.6354 @ epoch 11
#   THR_0.1_11_MaskOnly | Epoch 12/15 | train_loss=0.3280 | val_loss=0.3170 | val_acc=0.6370 | best=0.6370 @ epoch 12
#   THR_0.1_11_MaskOnly | Epoch 13/15 | train_loss=0.3224 | val_loss=0.3165 | val_acc=0.6460 | best=0.6460 @ epoch 13
#   THR_0.1_11_MaskOnly | Epoch 14/15 | train_loss=0.3172 | val_loss=0.3098 | val_acc=0.6500 | best=0.6500 @ epoch 14
#   THR_0.1_11_MaskOnly | Epoch 15/15 | train_loss=0.3123 | val_loss=0.3053 | val_acc=0.6532 | best=0.6532 @ epoch 15
#   THR_0.1_11_Full_CapFG | Epoch 01/15 | train_loss=0.5674 | val_loss=0.4807 | val_acc=0.4204 | best=0.4204 @ epoch 1
#   THR_0.1_11_Full_CapFG | Epoch 02/15 | train_loss=0.4725 | val_loss=0.4400 | val_acc=0.4720 | best=0.4720 @ epoch 2
#   THR_0.1_11_Full_CapFG | Epoch 03/15 | train_loss=0.4400 | val_loss=0.4120 | val_acc=0.5168 | best=0.5168 @ epoch 3
#   THR_0.1_11_Full_CapFG | Epoch 04/15 | train_loss=0.4148 | val_loss=0.3965 | val_acc=0.5376 | best=0.5376 @ epoch 4
#   THR_0.1_11_Full_CapFG | Epoch 05/15 | train_loss=0.3940 | val_loss=0.3866 | val_acc=0.5634 | best=0.5634 @ epoch 5
#   THR_0.1_11_Full_CapFG | Epoch 06/15 | train_loss=0.3788 | val_loss=0.3606 | val_acc=0.5728 | best=0.5728 @ epoch 6
#   THR_0.1_11_Full_CapFG | Epoch 07/15 | train_loss=0.3652 | val_loss=0.3679 | val_acc=0.5794 | best=0.5794 @ epoch 7
#   THR_0.1_11_Full_CapFG | Epoch 08/15 | train_loss=0.3539 | val_loss=0.3402 | val_acc=0.6004 | best=0.6004 @ epoch 8
#   THR_0.1_11_Full_CapFG | Epoch 09/15 | train_loss=0.3423 | val_loss=0.3385 | val_acc=0.6046 | best=0.6046 @ epoch 9
#   THR_0.1_11_Full_CapFG | Epoch 10/15 | train_loss=0.3318 | val_loss=0.3337 | val_acc=0.6152 | best=0.6152 @ epoch 10
#   THR_0.1_11_Full_CapFG | Epoch 11/15 | train_loss=0.3245 | val_loss=0.3176 | val_acc=0.6420 | best=0.6420 @ epoch 11
#   THR_0.1_11_Full_CapFG | Epoch 12/15 | train_loss=0.3159 | val_loss=0.3151 | val_acc=0.6370 | best=0.6420 @ epoch 11
#   THR_0.1_11_Full_CapFG | Epoch 13/15 | train_loss=0.3093 | val_loss=0.3077 | val_acc=0.6448 | best=0.6448 @ epoch 13
#   THR_0.1_11_Full_CapFG | Epoch 14/15 | train_loss=0.3032 | val_loss=0.2963 | val_acc=0.6674 | best=0.6674 @ epoch 14
#   THR_0.1_11_Full_CapFG | Epoch 15/15 | train_loss=0.2969 | val_loss=0.2955 | val_acc=0.6674 | best=0.6674 @ epoch 14
#   THR_0.1_22_MaskOnly | Epoch 01/15 | train_loss=0.5571 | val_loss=0.4884 | val_acc=0.4104 | best=0.4104 @ epoch 1
#   THR_0.1_22_MaskOnly | Epoch 02/15 | train_loss=0.4756 | val_loss=0.4400 | val_acc=0.4718 | best=0.4718 @ epoch 2
#   THR_0.1_22_MaskOnly | Epoch 03/15 | train_loss=0.4425 | val_loss=0.4170 | val_acc=0.4956 | best=0.4956 @ epoch 3
#   THR_0.1_22_MaskOnly | Epoch 04/15 | train_loss=0.4215 | val_loss=0.3976 | val_acc=0.5342 | best=0.5342 @ epoch 4
#   THR_0.1_22_MaskOnly | Epoch 05/15 | train_loss=0.4014 | val_loss=0.3811 | val_acc=0.5602 | best=0.5602 @ epoch 5
#   THR_0.1_22_MaskOnly | Epoch 06/15 | train_loss=0.3870 | val_loss=0.3778 | val_acc=0.5638 | best=0.5638 @ epoch 6
#   THR_0.1_22_MaskOnly | Epoch 07/15 | train_loss=0.3748 | val_loss=0.3684 | val_acc=0.5712 | best=0.5712 @ epoch 7
#   THR_0.1_22_MaskOnly | Epoch 08/15 | train_loss=0.3625 | val_loss=0.3477 | val_acc=0.5952 | best=0.5952 @ epoch 8
#   THR_0.1_22_MaskOnly | Epoch 09/15 | train_loss=0.3519 | val_loss=0.3406 | val_acc=0.6098 | best=0.6098 @ epoch 9
#   THR_0.1_22_MaskOnly | Epoch 10/15 | train_loss=0.3442 | val_loss=0.3367 | val_acc=0.6100 | best=0.6100 @ epoch 10
#   THR_0.1_22_MaskOnly | Epoch 11/15 | train_loss=0.3363 | val_loss=0.3284 | val_acc=0.6364 | best=0.6364 @ epoch 11
#   THR_0.1_22_MaskOnly | Epoch 12/15 | train_loss=0.3299 | val_loss=0.3184 | val_acc=0.6542 | best=0.6542 @ epoch 12
#   THR_0.1_22_MaskOnly | Epoch 13/15 | train_loss=0.3245 | val_loss=0.3139 | val_acc=0.6456 | best=0.6542 @ epoch 12
#   THR_0.1_22_MaskOnly | Epoch 14/15 | train_loss=0.3181 | val_loss=0.3244 | val_acc=0.6178 | best=0.6542 @ epoch 12
#   THR_0.1_22_MaskOnly | Epoch 15/15 | train_loss=0.3142 | val_loss=0.3073 | val_acc=0.6516 | best=0.6542 @ epoch 12
#   THR_0.1_22_Full_CapFG | Epoch 01/15 | train_loss=0.5639 | val_loss=0.4754 | val_acc=0.4226 | best=0.4226 @ epoch 1
#   THR_0.1_22_Full_CapFG | Epoch 02/15 | train_loss=0.4819 | val_loss=0.4379 | val_acc=0.4762 | best=0.4762 @ epoch 2
#   THR_0.1_22_Full_CapFG | Epoch 03/15 | train_loss=0.4435 | val_loss=0.4206 | val_acc=0.5056 | best=0.5056 @ epoch 3
#   THR_0.1_22_Full_CapFG | Epoch 04/15 | train_loss=0.4176 | val_loss=0.3922 | val_acc=0.5356 | best=0.5356 @ epoch 4
#   THR_0.1_22_Full_CapFG | Epoch 05/15 | train_loss=0.3919 | val_loss=0.3755 | val_acc=0.5628 | best=0.5628 @ epoch 5
#   THR_0.1_22_Full_CapFG | Epoch 06/15 | train_loss=0.3737 | val_loss=0.3641 | val_acc=0.5858 | best=0.5858 @ epoch 6
#   THR_0.1_22_Full_CapFG | Epoch 07/15 | train_loss=0.3595 | val_loss=0.3550 | val_acc=0.5908 | best=0.5908 @ epoch 7
#   THR_0.1_22_Full_CapFG | Epoch 08/15 | train_loss=0.3471 | val_loss=0.3331 | val_acc=0.6242 | best=0.6242 @ epoch 8
#   THR_0.1_22_Full_CapFG | Epoch 09/15 | train_loss=0.3330 | val_loss=0.3275 | val_acc=0.6128 | best=0.6242 @ epoch 8
#   THR_0.1_22_Full_CapFG | Epoch 10/15 | train_loss=0.3241 | val_loss=0.3169 | val_acc=0.6306 | best=0.6306 @ epoch 10
#   THR_0.1_22_Full_CapFG | Epoch 11/15 | train_loss=0.3150 | val_loss=0.3180 | val_acc=0.6382 | best=0.6382 @ epoch 11
#   THR_0.1_22_Full_CapFG | Epoch 12/15 | train_loss=0.3085 | val_loss=0.3053 | val_acc=0.6528 | best=0.6528 @ epoch 12
#   THR_0.1_22_Full_CapFG | Epoch 13/15 | train_loss=0.3020 | val_loss=0.3009 | val_acc=0.6622 | best=0.6622 @ epoch 13
#   THR_0.1_22_Full_CapFG | Epoch 14/15 | train_loss=0.2957 | val_loss=0.2917 | val_acc=0.6654 | best=0.6654 @ epoch 14
#   THR_0.1_22_Full_CapFG | Epoch 15/15 | train_loss=0.2891 | val_loss=0.2875 | val_acc=0.6782 | best=0.6782 @ epoch 15
#   THR_0.1_33_MaskOnly | Epoch 01/15 | train_loss=0.5573 | val_loss=0.4922 | val_acc=0.3856 | best=0.3856 @ epoch 1
#   THR_0.1_33_MaskOnly | Epoch 02/15 | train_loss=0.4764 | val_loss=0.4429 | val_acc=0.4514 | best=0.4514 @ epoch 2
#   THR_0.1_33_MaskOnly | Epoch 03/15 | train_loss=0.4476 | val_loss=0.4257 | val_acc=0.4848 | best=0.4848 @ epoch 3
#   THR_0.1_33_MaskOnly | Epoch 04/15 | train_loss=0.4230 | val_loss=0.4101 | val_acc=0.5156 | best=0.5156 @ epoch 4
#   THR_0.1_33_MaskOnly | Epoch 05/15 | train_loss=0.4019 | val_loss=0.3935 | val_acc=0.5366 | best=0.5366 @ epoch 5
#   THR_0.1_33_MaskOnly | Epoch 06/15 | train_loss=0.3872 | val_loss=0.3790 | val_acc=0.5592 | best=0.5592 @ epoch 6
#   THR_0.1_33_MaskOnly | Epoch 07/15 | train_loss=0.3757 | val_loss=0.3738 | val_acc=0.5546 | best=0.5592 @ epoch 6
#   THR_0.1_33_MaskOnly | Epoch 08/15 | train_loss=0.3664 | val_loss=0.3577 | val_acc=0.5918 | best=0.5918 @ epoch 8
#   THR_0.1_33_MaskOnly | Epoch 09/15 | train_loss=0.3575 | val_loss=0.3491 | val_acc=0.5976 | best=0.5976 @ epoch 9
#   THR_0.1_33_MaskOnly | Epoch 10/15 | train_loss=0.3510 | val_loss=0.3396 | val_acc=0.6088 | best=0.6088 @ epoch 10
#   THR_0.1_33_MaskOnly | Epoch 11/15 | train_loss=0.3432 | val_loss=0.3389 | val_acc=0.5928 | best=0.6088 @ epoch 10
#   THR_0.1_33_MaskOnly | Epoch 12/15 | train_loss=0.3376 | val_loss=0.3309 | val_acc=0.6256 | best=0.6256 @ epoch 12
#   THR_0.1_33_MaskOnly | Epoch 13/15 | train_loss=0.3325 | val_loss=0.3329 | val_acc=0.6110 | best=0.6256 @ epoch 12
#   THR_0.1_33_MaskOnly | Epoch 14/15 | train_loss=0.3280 | val_loss=0.3249 | val_acc=0.6210 | best=0.6256 @ epoch 12
#   THR_0.1_33_MaskOnly | Epoch 15/15 | train_loss=0.3217 | val_loss=0.3195 | val_acc=0.6378 | best=0.6378 @ epoch 15
#   THR_0.1_33_Full_CapFG | Epoch 01/15 | train_loss=0.5664 | val_loss=0.4725 | val_acc=0.4202 | best=0.4202 @ epoch 1
#   THR_0.1_33_Full_CapFG | Epoch 02/15 | train_loss=0.4748 | val_loss=0.4352 | val_acc=0.4828 | best=0.4828 @ epoch 2
#   THR_0.1_33_Full_CapFG | Epoch 03/15 | train_loss=0.4376 | val_loss=0.4108 | val_acc=0.5088 | best=0.5088 @ epoch 3
#   THR_0.1_33_Full_CapFG | Epoch 04/15 | train_loss=0.4152 | val_loss=0.3883 | val_acc=0.5522 | best=0.5522 @ epoch 4
#   THR_0.1_33_Full_CapFG | Epoch 05/15 | train_loss=0.3879 | val_loss=0.3697 | val_acc=0.5826 | best=0.5826 @ epoch 5
#   THR_0.1_33_Full_CapFG | Epoch 06/15 | train_loss=0.3672 | val_loss=0.3706 | val_acc=0.5618 | best=0.5826 @ epoch 5
#   THR_0.1_33_Full_CapFG | Epoch 07/15 | train_loss=0.3492 | val_loss=0.3357 | val_acc=0.6176 | best=0.6176 @ epoch 7
#   THR_0.1_33_Full_CapFG | Epoch 08/15 | train_loss=0.3378 | val_loss=0.3267 | val_acc=0.6282 | best=0.6282 @ epoch 8
#   THR_0.1_33_Full_CapFG | Epoch 09/15 | train_loss=0.3280 | val_loss=0.3129 | val_acc=0.6548 | best=0.6548 @ epoch 9
#   THR_0.1_33_Full_CapFG | Epoch 10/15 | train_loss=0.3174 | val_loss=0.3111 | val_acc=0.6458 | best=0.6548 @ epoch 9
#   THR_0.1_33_Full_CapFG | Epoch 11/15 | train_loss=0.3106 | val_loss=0.3008 | val_acc=0.6624 | best=0.6624 @ epoch 11
#   THR_0.1_33_Full_CapFG | Epoch 12/15 | train_loss=0.3025 | val_loss=0.3072 | val_acc=0.6420 | best=0.6624 @ epoch 11
#   THR_0.1_33_Full_CapFG | Epoch 13/15 | train_loss=0.2951 | val_loss=0.2981 | val_acc=0.6594 | best=0.6624 @ epoch 11
#   THR_0.1_33_Full_CapFG | Epoch 14/15 | train_loss=0.2892 | val_loss=0.2914 | val_acc=0.6778 | best=0.6778 @ epoch 14
#   THR_0.1_33_Full_CapFG | Epoch 15/15 | train_loss=0.2851 | val_loss=0.2902 | val_acc=0.6682 | best=0.6778 @ epoch 14
#   THR_0.15_11_MaskOnly | Epoch 01/15 | train_loss=0.5572 | val_loss=0.4789 | val_acc=0.4254 | best=0.4254 @ epoch 1
#   THR_0.15_11_MaskOnly | Epoch 02/15 | train_loss=0.4699 | val_loss=0.4296 | val_acc=0.4882 | best=0.4882 @ epoch 2
#   THR_0.15_11_MaskOnly | Epoch 03/15 | train_loss=0.4378 | val_loss=0.4143 | val_acc=0.4994 | best=0.4994 @ epoch 3
#   THR_0.15_11_MaskOnly | Epoch 04/15 | train_loss=0.4124 | val_loss=0.3898 | val_acc=0.5446 | best=0.5446 @ epoch 4
#   THR_0.15_11_MaskOnly | Epoch 05/15 | train_loss=0.3875 | val_loss=0.3748 | val_acc=0.5692 | best=0.5692 @ epoch 5
#   THR_0.15_11_MaskOnly | Epoch 06/15 | train_loss=0.3718 | val_loss=0.3578 | val_acc=0.5970 | best=0.5970 @ epoch 6
#   THR_0.15_11_MaskOnly | Epoch 07/15 | train_loss=0.3600 | val_loss=0.3466 | val_acc=0.6050 | best=0.6050 @ epoch 7
#   THR_0.15_11_MaskOnly | Epoch 08/15 | train_loss=0.3496 | val_loss=0.3421 | val_acc=0.6092 | best=0.6092 @ epoch 8
#   THR_0.15_11_MaskOnly | Epoch 09/15 | train_loss=0.3411 | val_loss=0.3318 | val_acc=0.6250 | best=0.6250 @ epoch 9
#   THR_0.15_11_MaskOnly | Epoch 10/15 | train_loss=0.3342 | val_loss=0.3221 | val_acc=0.6280 | best=0.6280 @ epoch 10
#   THR_0.15_11_MaskOnly | Epoch 11/15 | train_loss=0.3269 | val_loss=0.3226 | val_acc=0.6396 | best=0.6396 @ epoch 11
#   THR_0.15_11_MaskOnly | Epoch 12/15 | train_loss=0.3209 | val_loss=0.3120 | val_acc=0.6494 | best=0.6494 @ epoch 12
#   THR_0.15_11_MaskOnly | Epoch 13/15 | train_loss=0.3151 | val_loss=0.3070 | val_acc=0.6590 | best=0.6590 @ epoch 13
#   THR_0.15_11_MaskOnly | Epoch 14/15 | train_loss=0.3108 | val_loss=0.3050 | val_acc=0.6608 | best=0.6608 @ epoch 14
#   THR_0.15_11_MaskOnly | Epoch 15/15 | train_loss=0.3065 | val_loss=0.3010 | val_acc=0.6636 | best=0.6636 @ epoch 15
#   THR_0.15_11_Full_CapFG | Epoch 01/15 | train_loss=0.5657 | val_loss=0.4842 | val_acc=0.4110 | best=0.4110 @ epoch 1
#   THR_0.15_11_Full_CapFG | Epoch 02/15 | train_loss=0.4672 | val_loss=0.4365 | val_acc=0.4716 | best=0.4716 @ epoch 2
#   THR_0.15_11_Full_CapFG | Epoch 03/15 | train_loss=0.4311 | val_loss=0.4014 | val_acc=0.5290 | best=0.5290 @ epoch 3
#   THR_0.15_11_Full_CapFG | Epoch 04/15 | train_loss=0.4043 | val_loss=0.3875 | val_acc=0.5514 | best=0.5514 @ epoch 4
#   THR_0.15_11_Full_CapFG | Epoch 05/15 | train_loss=0.3834 | val_loss=0.3728 | val_acc=0.5662 | best=0.5662 @ epoch 5
#   THR_0.15_11_Full_CapFG | Epoch 06/15 | train_loss=0.3703 | val_loss=0.3596 | val_acc=0.5730 | best=0.5730 @ epoch 6
#   THR_0.15_11_Full_CapFG | Epoch 07/15 | train_loss=0.3560 | val_loss=0.3492 | val_acc=0.5944 | best=0.5944 @ epoch 7
#   THR_0.15_11_Full_CapFG | Epoch 08/15 | train_loss=0.3464 | val_loss=0.3333 | val_acc=0.6122 | best=0.6122 @ epoch 8
#   THR_0.15_11_Full_CapFG | Epoch 09/15 | train_loss=0.3344 | val_loss=0.3385 | val_acc=0.5998 | best=0.6122 @ epoch 8
#   THR_0.15_11_Full_CapFG | Epoch 10/15 | train_loss=0.3245 | val_loss=0.3255 | val_acc=0.6236 | best=0.6236 @ epoch 10
#   THR_0.15_11_Full_CapFG | Epoch 11/15 | train_loss=0.3181 | val_loss=0.3146 | val_acc=0.6398 | best=0.6398 @ epoch 11
#   THR_0.15_11_Full_CapFG | Epoch 12/15 | train_loss=0.3102 | val_loss=0.3116 | val_acc=0.6404 | best=0.6404 @ epoch 12
#   THR_0.15_11_Full_CapFG | Epoch 13/15 | train_loss=0.3040 | val_loss=0.3021 | val_acc=0.6550 | best=0.6550 @ epoch 13
#   THR_0.15_11_Full_CapFG | Epoch 14/15 | train_loss=0.2969 | val_loss=0.2952 | val_acc=0.6628 | best=0.6628 @ epoch 14
#   THR_0.15_11_Full_CapFG | Epoch 15/15 | train_loss=0.2916 | val_loss=0.2915 | val_acc=0.6702 | best=0.6702 @ epoch 15
#   THR_0.15_22_MaskOnly | Epoch 01/15 | train_loss=0.5537 | val_loss=0.4943 | val_acc=0.4018 | best=0.4018 @ epoch 1
#   THR_0.15_22_MaskOnly | Epoch 02/15 | train_loss=0.4715 | val_loss=0.4338 | val_acc=0.4772 | best=0.4772 @ epoch 2
#   THR_0.15_22_MaskOnly | Epoch 03/15 | train_loss=0.4382 | val_loss=0.4122 | val_acc=0.5060 | best=0.5060 @ epoch 3
#   THR_0.15_22_MaskOnly | Epoch 04/15 | train_loss=0.4106 | val_loss=0.3931 | val_acc=0.5534 | best=0.5534 @ epoch 4
#   THR_0.15_22_MaskOnly | Epoch 05/15 | train_loss=0.3902 | val_loss=0.3730 | val_acc=0.5808 | best=0.5808 @ epoch 5
#   THR_0.15_22_MaskOnly | Epoch 06/15 | train_loss=0.3744 | val_loss=0.3650 | val_acc=0.5840 | best=0.5840 @ epoch 6
#   THR_0.15_22_MaskOnly | Epoch 07/15 | train_loss=0.3630 | val_loss=0.3513 | val_acc=0.6016 | best=0.6016 @ epoch 7
#   THR_0.15_22_MaskOnly | Epoch 08/15 | train_loss=0.3515 | val_loss=0.3381 | val_acc=0.6226 | best=0.6226 @ epoch 8
#   THR_0.15_22_MaskOnly | Epoch 09/15 | train_loss=0.3410 | val_loss=0.3306 | val_acc=0.6246 | best=0.6246 @ epoch 9
#   THR_0.15_22_MaskOnly | Epoch 10/15 | train_loss=0.3335 | val_loss=0.3239 | val_acc=0.6334 | best=0.6334 @ epoch 10
#   THR_0.15_22_MaskOnly | Epoch 11/15 | train_loss=0.3253 | val_loss=0.3166 | val_acc=0.6482 | best=0.6482 @ epoch 11
#   THR_0.15_22_MaskOnly | Epoch 12/15 | train_loss=0.3204 | val_loss=0.3093 | val_acc=0.6652 | best=0.6652 @ epoch 12
#   THR_0.15_22_MaskOnly | Epoch 13/15 | train_loss=0.3138 | val_loss=0.3016 | val_acc=0.6664 | best=0.6664 @ epoch 13
#   THR_0.15_22_MaskOnly | Epoch 14/15 | train_loss=0.3080 | val_loss=0.3131 | val_acc=0.6440 | best=0.6664 @ epoch 13
#   THR_0.15_22_MaskOnly | Epoch 15/15 | train_loss=0.3036 | val_loss=0.2982 | val_acc=0.6780 | best=0.6780 @ epoch 15
#   THR_0.15_22_Full_CapFG | Epoch 01/15 | train_loss=0.5631 | val_loss=0.4751 | val_acc=0.4252 | best=0.4252 @ epoch 1
#   THR_0.15_22_Full_CapFG | Epoch 02/15 | train_loss=0.4790 | val_loss=0.4359 | val_acc=0.4824 | best=0.4824 @ epoch 2
#   THR_0.15_22_Full_CapFG | Epoch 03/15 | train_loss=0.4394 | val_loss=0.4119 | val_acc=0.5292 | best=0.5292 @ epoch 3
#   THR_0.15_22_Full_CapFG | Epoch 04/15 | train_loss=0.4152 | val_loss=0.3915 | val_acc=0.5414 | best=0.5414 @ epoch 4
#   THR_0.15_22_Full_CapFG | Epoch 05/15 | train_loss=0.3899 | val_loss=0.3768 | val_acc=0.5676 | best=0.5676 @ epoch 5
#   THR_0.15_22_Full_CapFG | Epoch 06/15 | train_loss=0.3694 | val_loss=0.3534 | val_acc=0.5982 | best=0.5982 @ epoch 6
#   THR_0.15_22_Full_CapFG | Epoch 07/15 | train_loss=0.3539 | val_loss=0.3414 | val_acc=0.6080 | best=0.6080 @ epoch 7
#   THR_0.15_22_Full_CapFG | Epoch 08/15 | train_loss=0.3415 | val_loss=0.3352 | val_acc=0.6136 | best=0.6136 @ epoch 8
#   THR_0.15_22_Full_CapFG | Epoch 09/15 | train_loss=0.3278 | val_loss=0.3242 | val_acc=0.6208 | best=0.6208 @ epoch 9
#   THR_0.15_22_Full_CapFG | Epoch 10/15 | train_loss=0.3198 | val_loss=0.3187 | val_acc=0.6344 | best=0.6344 @ epoch 10
#   THR_0.15_22_Full_CapFG | Epoch 11/15 | train_loss=0.3102 | val_loss=0.3032 | val_acc=0.6570 | best=0.6570 @ epoch 11
#   THR_0.15_22_Full_CapFG | Epoch 12/15 | train_loss=0.3031 | val_loss=0.3009 | val_acc=0.6614 | best=0.6614 @ epoch 12
#   THR_0.15_22_Full_CapFG | Epoch 13/15 | train_loss=0.2966 | val_loss=0.2931 | val_acc=0.6704 | best=0.6704 @ epoch 13
#   THR_0.15_22_Full_CapFG | Epoch 14/15 | train_loss=0.2903 | val_loss=0.2857 | val_acc=0.6794 | best=0.6794 @ epoch 14
# ...
#   STAT_seed99_Baseline | Epoch 23/30 | train_loss=0.2827 | val_loss=0.2817 | val_acc=0.6938 | best=0.6938 @ epoch 23
#   STAT_seed99_Baseline | Epoch 24/30 | train_loss=0.2813 | val_loss=0.2798 | val_acc=0.6974 | best=0.6974 @ epoch 24
#   STAT_seed99_Baseline | Epoch 25/30 | train_loss=0.2788 | val_loss=0.2790 | val_acc=0.6958 | best=0.6974 @ epoch 24
#   STAT_seed99_Baseline | Epoch 26/30 | train_loss=0.2768 | val_loss=0.2757 | val_acc=0.7024 | best=0.7024 @ epoch 26
#   STAT_seed99_Baseline | Epoch 27/30 | train_loss=0.2742 | val_loss=0.2762 | val_acc=0.6988 | best=0.7024 @ epoch 26
#   STAT_seed99_Baseline | Epoch 28/30 | train_loss=0.2732 | val_loss=0.2747 | val_acc=0.7044 | best=0.7044 @ epoch 28
#   STAT_seed99_Baseline | Epoch 29/30 | train_loss=0.2724 | val_loss=0.2732 | val_acc=0.7090 | best=0.7090 @ epoch 29
#   STAT_seed99_Baseline | Epoch 30/30 | train_loss=0.2704 | val_loss=0.2724 | val_acc=0.7106 | best=0.7106 @ epoch 30
#
# --- Statistical validation | seed=99 | Full_CapFG ---
#   STAT_seed99_Full_CapFG | Epoch 01/30 | train_loss=0.5647 | val_loss=0.4777 | val_acc=0.4034 | best=0.4034 @ epoch 1
#   STAT_seed99_Full_CapFG | Epoch 02/30 | train_loss=0.4731 | val_loss=0.4318 | val_acc=0.4884 | best=0.4884 @ epoch 2
#   STAT_seed99_Full_CapFG | Epoch 03/30 | train_loss=0.4391 | val_loss=0.4125 | val_acc=0.5214 | best=0.5214 @ epoch 3
#   STAT_seed99_Full_CapFG | Epoch 04/30 | train_loss=0.4122 | val_loss=0.3890 | val_acc=0.5448 | best=0.5448 @ epoch 4
#   STAT_seed99_Full_CapFG | Epoch 05/30 | train_loss=0.3917 | val_loss=0.3755 | val_acc=0.5614 | best=0.5614 @ epoch 5
#   STAT_seed99_Full_CapFG | Epoch 06/30 | train_loss=0.3766 | val_loss=0.3613 | val_acc=0.5826 | best=0.5826 @ epoch 6
#   STAT_seed99_Full_CapFG | Epoch 07/30 | train_loss=0.3628 | val_loss=0.3459 | val_acc=0.6044 | best=0.6044 @ epoch 7
#   STAT_seed99_Full_CapFG | Epoch 08/30 | train_loss=0.3512 | val_loss=0.3401 | val_acc=0.6058 | best=0.6058 @ epoch 8
#   STAT_seed99_Full_CapFG | Epoch 09/30 | train_loss=0.3414 | val_loss=0.3364 | val_acc=0.6146 | best=0.6146 @ epoch 9
#   STAT_seed99_Full_CapFG | Epoch 10/30 | train_loss=0.3323 | val_loss=0.3231 | val_acc=0.6302 | best=0.6302 @ epoch 10
#   STAT_seed99_Full_CapFG | Epoch 11/30 | train_loss=0.3220 | val_loss=0.3227 | val_acc=0.6348 | best=0.6348 @ epoch 11
#   STAT_seed99_Full_CapFG | Epoch 12/30 | train_loss=0.3142 | val_loss=0.3142 | val_acc=0.6474 | best=0.6474 @ epoch 12
#   STAT_seed99_Full_CapFG | Epoch 13/30 | train_loss=0.3061 | val_loss=0.3003 | val_acc=0.6630 | best=0.6630 @ epoch 13
#   STAT_seed99_Full_CapFG | Epoch 14/30 | train_loss=0.3015 | val_loss=0.2987 | val_acc=0.6688 | best=0.6688 @ epoch 14
#   STAT_seed99_Full_CapFG | Epoch 15/30 | train_loss=0.2956 | val_loss=0.2956 | val_acc=0.6724 | best=0.6724 @ epoch 15
#   STAT_seed99_Full_CapFG | Epoch 16/30 | train_loss=0.2895 | val_loss=0.2884 | val_acc=0.6798 | best=0.6798 @ epoch 16
#   STAT_seed99_Full_CapFG | Epoch 17/30 | train_loss=0.2841 | val_loss=0.2864 | val_acc=0.6786 | best=0.6798 @ epoch 16
#   STAT_seed99_Full_CapFG | Epoch 18/30 | train_loss=0.2817 | val_loss=0.2873 | val_acc=0.6740 | best=0.6798 @ epoch 16
#   STAT_seed99_Full_CapFG | Epoch 19/30 | train_loss=0.2777 | val_loss=0.2823 | val_acc=0.6784 | best=0.6798 @ epoch 16
#   STAT_seed99_Full_CapFG | Epoch 20/30 | train_loss=0.2735 | val_loss=0.2787 | val_acc=0.6928 | best=0.6928 @ epoch 20
#   STAT_seed99_Full_CapFG | Epoch 21/30 | train_loss=0.2707 | val_loss=0.2744 | val_acc=0.6936 | best=0.6936 @ epoch 21
#   STAT_seed99_Full_CapFG | Epoch 22/30 | train_loss=0.2676 | val_loss=0.2765 | val_acc=0.6926 | best=0.6936 @ epoch 21
#   STAT_seed99_Full_CapFG | Epoch 23/30 | train_loss=0.2645 | val_loss=0.2725 | val_acc=0.6924 | best=0.6936 @ epoch 21
#   STAT_seed99_Full_CapFG | Epoch 24/30 | train_loss=0.2632 | val_loss=0.2682 | val_acc=0.7036 | best=0.7036 @ epoch 24
#   STAT_seed99_Full_CapFG | Epoch 25/30 | train_loss=0.2614 | val_loss=0.2686 | val_acc=0.6974 | best=0.7036 @ epoch 24
#   STAT_seed99_Full_CapFG | Epoch 26/30 | train_loss=0.2584 | val_loss=0.2664 | val_acc=0.7058 | best=0.7058 @ epoch 26
#   STAT_seed99_Full_CapFG | Epoch 27/30 | train_loss=0.2571 | val_loss=0.2677 | val_acc=0.7016 | best=0.7058 @ epoch 26
#   STAT_seed99_Full_CapFG | Epoch 28/30 | train_loss=0.2546 | val_loss=0.2636 | val_acc=0.7134 | best=0.7134 @ epoch 28
#   STAT_seed99_Full_CapFG | Epoch 29/30 | train_loss=0.2538 | val_loss=0.2624 | val_acc=0.7142 | best=0.7142 @ epoch 29
#   STAT_seed99_Full_CapFG | Epoch 30/30 | train_loss=0.2526 | val_loss=0.2669 | val_acc=0.7090 | best=0.7142 @ epoch 29
#
# ================ STATISTICAL RUN: seed=101 ================
#
# --- Statistical validation | seed=101 | Baseline ---
#   STAT_seed101_Baseline | Epoch 01/30 | train_loss=0.5665 | val_loss=0.4833 | val_acc=0.4250 | best=0.4250 @ epoch 1
#   STAT_seed101_Baseline | Epoch 02/30 | train_loss=0.4772 | val_loss=0.4553 | val_acc=0.4680 | best=0.4680 @ epoch 2
#   STAT_seed101_Baseline | Epoch 03/30 | train_loss=0.4465 | val_loss=0.4190 | val_acc=0.4942 | best=0.4942 @ epoch 3
#   STAT_seed101_Baseline | Epoch 04/30 | train_loss=0.4232 | val_loss=0.4027 | val_acc=0.5334 | best=0.5334 @ epoch 4
#   STAT_seed101_Baseline | Epoch 05/30 | train_loss=0.4020 | val_loss=0.3875 | val_acc=0.5386 | best=0.5386 @ epoch 5
#   STAT_seed101_Baseline | Epoch 06/30 | train_loss=0.3887 | val_loss=0.3741 | val_acc=0.5636 | best=0.5636 @ epoch 6
#   STAT_seed101_Baseline | Epoch 07/30 | train_loss=0.3757 | val_loss=0.3683 | val_acc=0.5558 | best=0.5636 @ epoch 6
#   STAT_seed101_Baseline | Epoch 08/30 | train_loss=0.3654 | val_loss=0.3544 | val_acc=0.5862 | best=0.5862 @ epoch 8
#   STAT_seed101_Baseline | Epoch 09/30 | train_loss=0.3554 | val_loss=0.3523 | val_acc=0.5806 | best=0.5862 @ epoch 8
#   STAT_seed101_Baseline | Epoch 10/30 | train_loss=0.3481 | val_loss=0.3396 | val_acc=0.6096 | best=0.6096 @ epoch 10
#   STAT_seed101_Baseline | Epoch 11/30 | train_loss=0.3405 | val_loss=0.3352 | val_acc=0.6134 | best=0.6134 @ epoch 11
#   STAT_seed101_Baseline | Epoch 12/30 | train_loss=0.3344 | val_loss=0.3285 | val_acc=0.6346 | best=0.6346 @ epoch 12
#   STAT_seed101_Baseline | Epoch 13/30 | train_loss=0.3278 | val_loss=0.3202 | val_acc=0.6340 | best=0.6346 @ epoch 12
#   STAT_seed101_Baseline | Epoch 14/30 | train_loss=0.3222 | val_loss=0.3175 | val_acc=0.6328 | best=0.6346 @ epoch 12
#   STAT_seed101_Baseline | Epoch 15/30 | train_loss=0.3176 | val_loss=0.3128 | val_acc=0.6474 | best=0.6474 @ epoch 15
#   STAT_seed101_Baseline | Epoch 16/30 | train_loss=0.3123 | val_loss=0.3104 | val_acc=0.6516 | best=0.6516 @ epoch 16
#   STAT_seed101_Baseline | Epoch 17/30 | train_loss=0.3089 | val_loss=0.3028 | val_acc=0.6616 | best=0.6616 @ epoch 17
#   STAT_seed101_Baseline | Epoch 18/30 | train_loss=0.3041 | val_loss=0.3010 | val_acc=0.6668 | best=0.6668 @ epoch 18
#   STAT_seed101_Baseline | Epoch 19/30 | train_loss=0.3006 | val_loss=0.2941 | val_acc=0.6732 | best=0.6732 @ epoch 19
#   STAT_seed101_Baseline | Epoch 20/30 | train_loss=0.2967 | val_loss=0.2930 | val_acc=0.6740 | best=0.6740 @ epoch 20
#   STAT_seed101_Baseline | Epoch 21/30 | train_loss=0.2942 | val_loss=0.2904 | val_acc=0.6770 | best=0.6770 @ epoch 21
#   STAT_seed101_Baseline | Epoch 22/30 | train_loss=0.2918 | val_loss=0.2907 | val_acc=0.6846 | best=0.6846 @ epoch 22
#   STAT_seed101_Baseline | Epoch 23/30 | train_loss=0.2890 | val_loss=0.2885 | val_acc=0.6846 | best=0.6846 @ epoch 22
#   STAT_seed101_Baseline | Epoch 24/30 | train_loss=0.2863 | val_loss=0.2843 | val_acc=0.6858 | best=0.6858 @ epoch 24
#   STAT_seed101_Baseline | Epoch 25/30 | train_loss=0.2849 | val_loss=0.2832 | val_acc=0.6876 | best=0.6876 @ epoch 25
#   STAT_seed101_Baseline | Epoch 26/30 | train_loss=0.2829 | val_loss=0.2827 | val_acc=0.6944 | best=0.6944 @ epoch 26
#   STAT_seed101_Baseline | Epoch 27/30 | train_loss=0.2814 | val_loss=0.2825 | val_acc=0.6948 | best=0.6948 @ epoch 27
#   STAT_seed101_Baseline | Epoch 28/30 | train_loss=0.2789 | val_loss=0.2794 | val_acc=0.6880 | best=0.6948 @ epoch 27
#   STAT_seed101_Baseline | Epoch 29/30 | train_loss=0.2780 | val_loss=0.2779 | val_acc=0.6920 | best=0.6948 @ epoch 27
#   STAT_seed101_Baseline | Epoch 30/30 | train_loss=0.2776 | val_loss=0.2787 | val_acc=0.6862 | best=0.6948 @ epoch 27
#
# --- Statistical validation | seed=101 | Full_CapFG ---
#   STAT_seed101_Full_CapFG | Epoch 01/30 | train_loss=0.5586 | val_loss=0.4748 | val_acc=0.4252 | best=0.4252 @ epoch 1
#   STAT_seed101_Full_CapFG | Epoch 02/30 | train_loss=0.4741 | val_loss=0.4351 | val_acc=0.4934 | best=0.4934 @ epoch 2
#   STAT_seed101_Full_CapFG | Epoch 03/30 | train_loss=0.4365 | val_loss=0.4122 | val_acc=0.5146 | best=0.5146 @ epoch 3
#   STAT_seed101_Full_CapFG | Epoch 04/30 | train_loss=0.4069 | val_loss=0.3815 | val_acc=0.5664 | best=0.5664 @ epoch 4
#   STAT_seed101_Full_CapFG | Epoch 05/30 | train_loss=0.3866 | val_loss=0.3678 | val_acc=0.5742 | best=0.5742 @ epoch 5
#   STAT_seed101_Full_CapFG | Epoch 06/30 | train_loss=0.3690 | val_loss=0.3643 | val_acc=0.5750 | best=0.5750 @ epoch 6
#   STAT_seed101_Full_CapFG | Epoch 07/30 | train_loss=0.3547 | val_loss=0.3474 | val_acc=0.6014 | best=0.6014 @ epoch 7
#   STAT_seed101_Full_CapFG | Epoch 08/30 | train_loss=0.3424 | val_loss=0.3282 | val_acc=0.6350 | best=0.6350 @ epoch 8
#   STAT_seed101_Full_CapFG | Epoch 09/30 | train_loss=0.3315 | val_loss=0.3265 | val_acc=0.6272 | best=0.6350 @ epoch 8
#   STAT_seed101_Full_CapFG | Epoch 10/30 | train_loss=0.3224 | val_loss=0.3196 | val_acc=0.6360 | best=0.6360 @ epoch 10
#   STAT_seed101_Full_CapFG | Epoch 11/30 | train_loss=0.3146 | val_loss=0.3090 | val_acc=0.6502 | best=0.6502 @ epoch 11
#   STAT_seed101_Full_CapFG | Epoch 12/30 | train_loss=0.3060 | val_loss=0.3037 | val_acc=0.6576 | best=0.6576 @ epoch 12
#   STAT_seed101_Full_CapFG | Epoch 13/30 | train_loss=0.2994 | val_loss=0.2991 | val_acc=0.6662 | best=0.6662 @ epoch 13
#   STAT_seed101_Full_CapFG | Epoch 14/30 | train_loss=0.2931 | val_loss=0.3238 | val_acc=0.6222 | best=0.6662 @ epoch 13
#   STAT_seed101_Full_CapFG | Epoch 15/30 | train_loss=0.2873 | val_loss=0.2905 | val_acc=0.6726 | best=0.6726 @ epoch 15
#   STAT_seed101_Full_CapFG | Epoch 16/30 | train_loss=0.2823 | val_loss=0.2803 | val_acc=0.6890 | best=0.6890 @ epoch 16
#   STAT_seed101_Full_CapFG | Epoch 17/30 | train_loss=0.2771 | val_loss=0.2790 | val_acc=0.6908 | best=0.6908 @ epoch 17
#   STAT_seed101_Full_CapFG | Epoch 18/30 | train_loss=0.2735 | val_loss=0.2821 | val_acc=0.6790 | best=0.6908 @ epoch 17
#   STAT_seed101_Full_CapFG | Epoch 19/30 | train_loss=0.2690 | val_loss=0.2723 | val_acc=0.6938 | best=0.6938 @ epoch 19
#   STAT_seed101_Full_CapFG | Epoch 20/30 | train_loss=0.2663 | val_loss=0.2686 | val_acc=0.7066 | best=0.7066 @ epoch 20
#   STAT_seed101_Full_CapFG | Epoch 21/30 | train_loss=0.2609 | val_loss=0.2692 | val_acc=0.7024 | best=0.7066 @ epoch 20
#   STAT_seed101_Full_CapFG | Epoch 22/30 | train_loss=0.2598 | val_loss=0.2636 | val_acc=0.7078 | best=0.7078 @ epoch 22
#   STAT_seed101_Full_CapFG | Epoch 23/30 | train_loss=0.2563 | val_loss=0.2657 | val_acc=0.7014 | best=0.7078 @ epoch 22
#   STAT_seed101_Full_CapFG | Epoch 24/30 | train_loss=0.2543 | val_loss=0.2650 | val_acc=0.7012 | best=0.7078 @ epoch 22
#   STAT_seed101_Full_CapFG | Epoch 25/30 | train_loss=0.2513 | val_loss=0.2664 | val_acc=0.6956 | best=0.7078 @ epoch 22
#   STAT_seed101_Full_CapFG | Epoch 26/30 | train_loss=0.2497 | val_loss=0.2576 | val_acc=0.7166 | best=0.7166 @ epoch 26
#   STAT_seed101_Full_CapFG | Epoch 27/30 | train_loss=0.2468 | val_loss=0.2563 | val_acc=0.7228 | best=0.7228 @ epoch 27
#   STAT_seed101_Full_CapFG | Epoch 28/30 | train_loss=0.2464 | val_loss=0.2554 | val_acc=0.7206 | best=0.7228 @ epoch 27
#   STAT_seed101_Full_CapFG | Epoch 29/30 | train_loss=0.2435 | val_loss=0.2577 | val_acc=0.7148 | best=0.7228 @ epoch 27
#   STAT_seed101_Full_CapFG | Epoch 30/30 | train_loss=0.2430 | val_loss=0.2575 | val_acc=0.7122 | best=0.7228 @ epoch 27
#
# === Repeated-run per-seed results ===
#     seed       model  best_val_acc  best_epoch  test_loss  test_acc
# 0     11    Baseline        0.6862          29   0.282674    0.6878
# 1     11  Full_CapFG        0.7104          30   0.261506    0.7148
# 2     22    Baseline        0.6886          29   0.285114    0.6910
# 3     22  Full_CapFG        0.7278          30   0.251041    0.7288
# 4     33    Baseline        0.6902          29   0.282506    0.6921
# 5     33  Full_CapFG        0.7212          30   0.254301    0.7207
# 6     44    Baseline        0.6936          29   0.281417    0.6940
# 7     44  Full_CapFG        0.7222          30   0.256589    0.7175
# 8     55    Baseline        0.6838          30   0.283673    0.6851
# 9     55  Full_CapFG        0.7104          30   0.261975    0.7098
# 10    66    Baseline        0.6810          30   0.286866    0.6897
# 11    66  Full_CapFG        0.7180          30   0.258499    0.7112
# 12    77    Baseline        0.7036          28   0.280132    0.6965
# 13    77  Full_CapFG        0.7168          29   0.251443    0.7263
# 14    88    Baseline        0.6736          29   0.286681    0.6843
# 15    88  Full_CapFG        0.7134          29   0.259595    0.7153
# 16    99    Baseline        0.7106          30   0.274365    0.7102
# 17    99  Full_CapFG        0.7142          29   0.262477    0.7068
# 18   101    Baseline        0.6948          27   0.281515    0.6981
# 19   101  Full_CapFG        0.7228          27   0.258330    0.7230
#
# === Descriptive statistical summary ===
#         model  n_runs  mean_test_acc  std_test_acc  ci95_low  ci95_high
# 0    Baseline      10        0.69288      0.007570  0.687464   0.698296
# 1  Full_CapFG      10        0.71742      0.007235  0.712244   0.722596
#
# === Paired inferential statistics ===
#               comparison  n_pairs  mean_difference  std_difference  \
# 0  Full_CapFG - Baseline       10          0.02454        0.010847
#
#    difference_ci95_low  difference_ci95_high  paired_t_statistic  \
# 0             0.016781              0.032299            7.154374
#
#    paired_t_pvalue  shapiro_difference_statistic  shapiro_difference_pvalue  \
# 0         0.000053                       0.77657                   0.007519
#
#    wilcoxon_statistic  wilcoxon_pvalue  cohens_dz
# 0                 1.0         0.003906   2.262412
#
# === Descriptive Statistical Summary ===
#         model  n_runs  mean_test_acc  std_test_acc  ci95_low  ci95_high
# 0    Baseline      10        0.69288      0.007570  0.687464   0.698296
# 1  Full_CapFG      10        0.71742      0.007235  0.712244   0.722596
#
# === Inferential Statistics (paired t-test, Wilcoxon, Cohen's dz) ===
#               comparison  n_pairs  mean_difference  std_difference  \
# 0  Full_CapFG - Baseline       10          0.02454        0.010847
#
#    difference_ci95_low  difference_ci95_high  paired_t_statistic  \
# 0             0.016781              0.032299            7.154374
#
#    paired_t_pvalue  shapiro_difference_statistic  shapiro_difference_pvalue  \
# 0         0.000053                       0.77657                   0.007519
#
#    wilcoxon_statistic  wilcoxon_pvalue  cohens_dz
# 0                 1.0         0.003906   2.262412
# Saved consolidated workbook: CapFG_COMPLETE_RESULTS.xlsx
#
# ✅ All analyses completed. Results saved as CSV files.
#    - cifar10_ablation_results.csv
#    - cifar10_routing_metrics.csv
#    - cifar10_shortcut_diagnostic.csv
#    - cifar10_noise_robustness.csv
#    - cifar10_computational_cost.csv
#    - cifar10_per_class_metrics.csv
#    - cifar10_training_dynamics.csv
#    - cifar10_training_history_representative.csv
#    - cifar10_macro_metrics.csv
#    - cifar10_confusion_matrix_baseline.csv
#    - cifar10_confusion_matrix_full_capfg.csv
#    - cifar10_confusion_matrices.png
#    - cifar10_training_dynamics.png
#    - cifar10_threshold_sensitivity_runs.csv
#    - cifar10_threshold_sensitivity_summary.csv
#    - pets_classification_results.csv
#    - pets_dice_scores.csv
#    - summary_metrics.csv
#    - cifar10_repeated_seed_runs.csv
#    - cifar10_paired_seed_accuracies.csv
#    - cifar10_statistical_summary.csv
#    - cifar10_inferential_statistics.csv
#    - CapFG_COMPLETE_RESULTS.xlsx
